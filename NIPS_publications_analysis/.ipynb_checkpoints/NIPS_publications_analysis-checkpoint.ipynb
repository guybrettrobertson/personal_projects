# %% [markdown]
# # NIPS Publications Analysis
#
# ## 1. Background
#
# The purpose of this project is to use data on published academic papers to investigate trends in machine learning research over recent decades (1987-2017). The data is an archive of 7,241 publications from the Neural Information Processing Systems (NIPS) conferences. This data has been obtained from Kaggle.com.

# %% [markdown]
# ## 2. Import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import wordcloud
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import warnings
from sklearn.decomposition import LatentDirichletAllocation as LDA

# %% [markdown]
# ## 3. Load NIPS data

# %%
# Read '~/Documents/data/NIPS_publications_analysis/papers.csv' into papers
papers = pd.read_csv('~/Documents/data/NIPS_publications_analysis/papers.csv')

# %%
# Print out the first rows of papers
print(papers.head())
# Out:
#      id  year                                              title event_type  \
# 0     1  1987  Self-Organization of Associative Database and ...        NaN
# 1    10  1987  A Mean Field Theory of Layer IV of Visual Cort...        NaN
# 2   100  1988  Storing Covariance by the Associative Long-Ter...        NaN
# 3  1000  1994  Bayesian Query Construction for Neural Network...        NaN
# 4  1001  1994  Neural Network Ensembles, Cross Validation, an...        NaN
#
#                                             pdf_name          abstract  \
# 0  1-self-organization-of-associative-database-an...  Abstract Missing
# 1  10-a-mean-field-theory-of-layer-iv-of-visual-c...  Abstract Missing
# 2  100-storing-covariance-by-the-associative-long...  Abstract Missing
# 3  1000-bayesian-query-construction-for-neural-ne...  Abstract Missing
# 4  1001-neural-network-ensembles-cross-validation...  Abstract Missing
#
#                                           paper_text
# 0  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3  Bayesian Query Construction for Neural\nNetwor...
# 4  Neural Network Ensembles, Cross\nValidation, a...

# %% [markdown]
# ## 4. Prepare the data for analysis
#
# For our analysis, we only need to keep each paper's text data as well as the year in which it was published. The other columns can therefore be removed.

# %%
# Print out the column names of papers
papers.columns
# Out:
# Index(['id', 'year', 'title', 'event_type', 'pdf_name', 'abstract',
#        'paper_text'],
#       dtype='object')

# %%
# Drop the columns: 'id', 'event_type', and 'pdf_name'
papers.drop(columns=['id', 'event_type', 'pdf_name'], axis=1, inplace=True)

# %%
# Print out the column names of papers
papers.columns
# Out:
# Index(['year', 'title', 'abstract', 'paper_text'], dtype='object')

# %%
# Print out the first rows of papers
print(papers.head())
# Out:
#    year                                              title          abstract  \
# 0  1987  Self-Organization of Associative Database and ...  Abstract Missing
# 1  1987  A Mean Field Theory of Layer IV of Visual Cort...  Abstract Missing
# 2  1988  Storing Covariance by the Associative Long-Ter...  Abstract Missing
# 3  1994  Bayesian Query Construction for Neural Network...  Abstract Missing
# 4  1994  Neural Network Ensembles, Cross Validation, an...  Abstract Missing
#
#                                           paper_text
# 0  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3  Bayesian Query Construction for Neural\nNetwor...
# 4  Neural Network Ensembles, Cross\nValidation, a...

# %% [markdown]
# ## 5. Visualise evolution of machine learning research over time

# %%
# Group the data by year
groups = papers.groupby('year')

# %%
# Find the size of each group
counts = groups.size()

# %%
# Plot the numbers of papers published each year
counts.plot(kind='line')
plt.title('Number of NIPS research papers published over time')
plt.ylabel('Number of NIPS research papers')
plt.show()

# %% [markdown]
# ## 6. Preprocess text data

# %%
# Print the titles of the first rows 
print(papers['title'].head())
# Out:
# 0    Self-Organization of Associative Database and ...
# 1    A Mean Field Theory of Layer IV of Visual Cort...
# 2    Storing Covariance by the Associative Long-Ter...
# 3    Bayesian Query Construction for Neural Network...
# 4    Neural Network Ensembles, Cross Validation, an...
# Name: title, dtype: object

# %%
# Remove punctuation
papers['title_processed'] = papers['title'].map(lambda x: re.sub('[,\.!?:]', '', x))

# Convert the titles to lowercase
papers['title_processed'] = papers['title_processed'].str.lower()

# Print the processed titles of the first rows 
print(papers['title_processed'].head())
# Out:
# 0    self-organization of associative database and ...
# 1    a mean field theory of layer iv of visual cort...
# 2    storing covariance by the associative long-ter...
# 3    bayesian query construction for neural network...
# 4    neural network ensembles cross validation and ...
# Name: title_processed, dtype: object

# %% [markdown]
# ## 7. Visualise preprocessed text data with a word cloud

# %%
# Join the different processed titles together.
long_string = ' '.join(papers['title_processed'])

# Create a WordCloud object
wc = wordcloud.WordCloud()

# Generate a wordcloud using long_string
wc.generate(long_string)

# Display wordcloud
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x130AAFE90>

# %% [markdown]
# ## 8. Prepare data for Latent Dirichlet Allocation
#
# Latent Dirichlet Allocation (LDA) is an unsupervised learning technique for natural language processing. Here we will use it to group the words in the research paper titles into topics, and then grouping the titles by topic.

# %%
# Helper function
def plot_10_most_common_words(count_data, count_vectorizer, year=None):
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 

    plt.bar(x_pos, counts,align='center')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('Words')
    plt.ylabel('Counts')
    if year == None:
        title = '10 most common words'
    else:
        title = str(year) + ': 10 most common words'
    plt.title(title)
    plt.show()

# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')

# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(papers['title_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)

# %% [markdown]
# ## 8. Analyse topics using LDA over whole period

# %%
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Hyperparameters
number_topics = 10
number_words = 3

# Create and fit the LDA model
lda = LDA(n_components=number_topics)
lda.fit(count_data)

# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# clustering based image
#
# Topic #1:
# learning multi large
#
# Topic #2:
# bounds boosting error
#
# Topic #3:
# learning reinforcement supervised
#
# Topic #4:
# time visual brain
#
# Topic #5:
# convex convergence optimization
#
# Topic #6:
# optimization selection robust
#
# Topic #7:
# neural networks network
#
# Topic #8:
# estimation learning matrix
#
# Topic #9:
# models gaussian inference

# %% [markdown]
# ## 9. Analyse changes in topics over time

# %%
# Hyperparameters
number_topics = 5
number_words = 4

# Iterate through each year of data
for year in papers['year'].unique():
    # Initialise the count vectorizer with the English stop words
    count_vectorizer = CountVectorizer(stop_words='english')

    # Fit and transform the processed titles
    count_data = count_vectorizer.fit_transform(papers[papers['year'] == year]['title_processed'])

    # Create and fit the LDA model
    lda = LDA(n_components=number_topics)
    lda.fit(count_data)

    # Print the topics found by the LDA model
    print('--------------', year, '--------------')
    print("Topics found via LDA:")
    print_topics(lda, count_vectorizer, number_words)
# Out:
# -------------- 1987 --------------
# Topics found via LDA:
#
# Topic #0:
# neurons processing associative memory
#
# Topic #1:
# learning neural network networks
#
# Topic #2:
# neural network networks artificial
#
# Topic #3:
# networks neural systems memories
#
# Topic #4:
# neural networks associative application
# -------------- 1988 --------------
# Topics found via LDA:
#
# Topic #0:
# learning network neural networks
#
# Topic #1:
# network connectionist sensory neural
#
# Topic #2:
# networks modeling analog learning
#
# Topic #3:
# neural networks analog recognition
#
# Topic #4:
# neural network learning networks
# -------------- 1994 --------------
# Topics found via LDA:
#
# Topic #0:
# neural networks learning model
#
# Topic #1:
# learning mixtures reinforcement using
#
# Topic #2:
# learning neural network cortex
#
# Topic #3:
# neural networks using network
#
# Topic #4:
# networks neural learning dynamic
# -------------- 1995 --------------
# Topics found via LDA:
#
# Topic #0:
# networks learning neural based
#
# Topic #1:
# model learning data recognition
#
# Topic #2:
# learning neural networks recurrent
#
# Topic #3:
# dynamic using training estimation
#
# Topic #4:
# neural networks network using
# -------------- 1996 --------------
# Topics found via LDA:
#
# Topic #0:
# learning neural networks model
#
# Topic #1:
# learning using classification problems
#
# Topic #2:
# using learning networks neural
#
# Topic #3:
# networks neural using learning
#
# Topic #4:
# models hidden markov algorithms
# -------------- 1997 --------------
# Topics found via LDA:
#
# Topic #0:
# learning natural model multi
#
# Topic #1:
# learning using analysis linear
#
# Topic #2:
# learning networks neural application
#
# Topic #3:
# model visual auditory using
#
# Topic #4:
# neural model networks learning
# -------------- 1998 --------------
# Topics found via LDA:
#
# Topic #0:
# learning algorithm reinforcement networks
#
# Topic #1:
# learning visual systems neural
#
# Topic #2:
# learning processes models gaussian
#
# Topic #3:
# learning reinforcement using vector
#
# Topic #4:
# learning data using models
# -------------- 1999 --------------
# Topics found via LDA:
#
# Topic #0:
# analysis recurrent audio using
#
# Topic #1:
# learning bayesian networks analysis
#
# Topic #2:
# learning approach models scale
#
# Topic #3:
# neural model information based
#
# Topic #4:
# data feature learning algorithms
# -------------- 2000 --------------
# Topics found via LDA:
#
# Topic #0:
# learning reinforcement algorithm models
#
# Topic #1:
# recognition speech robust new
#
# Topic #2:
# linear learning networks models
#
# Topic #3:
# learning using gaussian processes
#
# Topic #4:
# learning support vector based
# -------------- 1989 --------------
# Topics found via LDA:
#
# Topic #0:
# neural network networks propagation
#
# Topic #1:
# networks neural recognition connectionist
#
# Topic #2:
# networks learning model memory
#
# Topic #3:
# neural time computer organizing
#
# Topic #4:
# neural network using learning
# -------------- 2001 --------------
# Topics found via LDA:
#
# Topic #0:
# asymmetric spectral clustering likelihood
#
# Topic #1:
# learning model time neural
#
# Topic #2:
# approximation support value function
#
# Topic #3:
# using machines kernel vector
#
# Topic #4:
# learning reinforcement neural data
# -------------- 2002 --------------
# Topics found via LDA:
#
# Topic #0:
# based spike timing neural
#
# Topic #1:
# bayesian data learning time
#
# Topic #2:
# learning kernels information classification
#
# Topic #3:
# learning model based using
#
# Topic #4:
# learning analysis kernel function
# -------------- 2003 --------------
# Topics found via LDA:
#
# Topic #0:
# data margin neurons propagation
#
# Topic #1:
# classification learning gaussian multi
#
# Topic #2:
# learning bounds machines semi
#
# Topic #3:
# learning online approach support
#
# Topic #4:
# models non clustering learning
# -------------- 2004 --------------
# Topics found via LDA:
#
# Topic #0:
# information classification model models
#
# Topic #1:
# learning machine model tracking
#
# Topic #2:
# inference neural networks bayesian
#
# Topic #3:
# model using learning clustering
#
# Topic #4:
# learning supervised semi algorithms
# -------------- 2005 --------------
# Topics found via LDA:
#
# Topic #0:
# learning gaussian models using
#
# Topic #1:
# learning bounds algorithms active
#
# Topic #2:
# analysis learning activity sparse
#
# Topic #3:
# learning models networks clustering
#
# Topic #4:
# learning data visual kernel
# -------------- 1990 --------------
# Topics found via LDA:
#
# Topic #0:
# neural network memory learning
#
# Topic #1:
# learning neural networks using
#
# Topic #2:
# model connectionist recognition speech
#
# Topic #3:
# neural network networks learning
#
# Topic #4:
# neural networks network based
# -------------- 2006 --------------
# Topics found via LDA:
#
# Topic #0:
# learning bayesian graph analysis
#
# Topic #1:
# using learning models random
#
# Topic #2:
# clustering learning approach online
#
# Topic #3:
# learning gaussian data classification
#
# Topic #4:
# learning bayesian using clustering
# -------------- 2007 --------------
# Topics found via LDA:
#
# Topic #0:
# learning analysis inference using
#
# Topic #1:
# learning based neurons bayesian
#
# Topic #2:
# learning active classification modeling
#
# Topic #3:
# neural learning clustering vector
#
# Topic #4:
# model learning models sparse
# -------------- 2008 --------------
# Topics found via LDA:
#
# Topic #0:
# learning sparse models brain
#
# Topic #1:
# using regression clustering gaussian
#
# Topic #2:
# learning bayesian models using
#
# Topic #3:
# learning online regression large
#
# Topic #4:
# learning using bounds multiple
# -------------- 2009 --------------
# Topics found via LDA:
#
# Topic #0:
# learning bayesian models sparse
#
# Topic #1:
# feature recognition selection visual
#
# Topic #2:
# learning using semi supervised
#
# Topic #3:
# models learning analysis hierarchical
#
# Topic #4:
# learning multiple inference detection
# -------------- 2010 --------------
# Topics found via LDA:
#
# Topic #0:
# learning large multi processes
#
# Topic #1:
# learning optimization estimation large
#
# Topic #2:
# learning using analysis regularization
#
# Topic #3:
# learning inference models latent
#
# Topic #4:
# learning networks neural regression
# -------------- 2011 --------------
# Topics found via LDA:
#
# Topic #0:
# learning multi image using
#
# Topic #1:
# learning inference multi neural
#
# Topic #2:
# learning models large linear
#
# Topic #3:
# learning using prediction online
#
# Topic #4:
# learning models algorithms gaussian
# -------------- 1991 --------------
# Topics found via LDA:
#
# Topic #0:
# network learning neural adaptive
#
# Topic #1:
# learning recognition neural networks
#
# Topic #2:
# learning neural networks models
#
# Topic #3:
# neural networks network recognition
#
# Topic #4:
# neural temporal recognition forward
# -------------- 2012 --------------
# Topics found via LDA:
#
# Topic #0:
# learning models model nonparametric
#
# Topic #1:
# analysis learning using decision
#
# Topic #2:
# learning classification multi graphical
#
# Topic #3:
# learning kernel optimization based
#
# Topic #4:
# learning sparse networks probabilistic
# -------------- 2013 --------------
# Topics found via LDA:
#
# Topic #0:
# learning inference models fast
#
# Topic #1:
# optimization learning stochastic deep
#
# Topic #2:
# learning generalized models neural
#
# Topic #3:
# learning inference process models
#
# Topic #4:
# learning robust models multi
# -------------- 2014 --------------
# Topics found via LDA:
#
# Topic #0:
# models learning inference data
#
# Topic #1:
# models rank inference low
#
# Topic #2:
# learning sparse optimization neural
#
# Topic #3:
# deep learning bayesian using
#
# Topic #4:
# learning distributed networks model
# -------------- 2015 --------------
# Topics found via LDA:
#
# Topic #0:
# networks learning deep neural
#
# Topic #1:
# data gaussian dimensional high
#
# Topic #2:
# learning inference bandits bounds
#
# Topic #3:
# learning networks stochastic models
#
# Topic #4:
# optimization learning estimation models
# -------------- 1992 --------------
# Topics found via LDA:
#
# Topic #0:
# neural learning networks using
#
# Topic #1:
# learning networks neural weight
#
# Topic #2:
# neural networks analog model
#
# Topic #3:
# using learning network neural
#
# Topic #4:
# networks neural network hidden
# -------------- 2016 --------------
# Topics found via LDA:
#
# Topic #0:
# networks learning neural bayesian
#
# Topic #1:
# stochastic optimization gradient learning
#
# Topic #2:
# learning inference models variational
#
# Topic #3:
# learning deep optimal optimization
#
# Topic #4:
# learning networks models neural
# -------------- 2017 --------------
# Topics found via LDA:
#
# Topic #0:
# learning estimation clustering matrix
#
# Topic #1:
# neural stochastic optimization adaptive
#
# Topic #2:
# learning online regression approximation
#
# Topic #3:
# networks neural learning models
#
# Topic #4:
# learning deep variational inference
# -------------- 1993 --------------
# Topics found via LDA:
#
# Topic #0:
# networks learning neural models
#
# Topic #1:
# network neural using backpropagation
#
# Topic #2:
# networks neural learning using
#
# Topic #3:
# learning dynamic recognition using
#
# Topic #4:
# neural network learning classification
