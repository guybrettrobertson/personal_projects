# %% [markdown]
# # Audio data classification

# %% [markdown]
# ### Import packages

# %%
import pandas as pd

# %% [markdown]
# ## Run prior notebooks

# %%
# %run 02_investigate_correlations.ipynb
# Out:
# First few rows
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2       341      0.977282      0.468808  0.134975          0.687700  0.105381
# 3     46204      0.953349      0.498525  0.552503          0.924391  0.684914
# 4     46205      0.613229      0.500320  0.487992          0.936811  0.637750
#
#    speechiness    tempo   valence genre_top
# 0     0.159310  165.922  0.576661   Hip-Hop
# 1     0.461818  126.957  0.269240   Hip-Hop
# 2     0.073124  119.646  0.430707      Rock
# 3     0.028885   78.958  0.430448      Rock
# 4     0.030327  112.667  0.824749      Rock
# Features summary statistics
#             track_id  acousticness  danceability       energy  \
# count    4802.000000  4.802000e+03   4802.000000  4802.000000
# ...

# %% [markdown]
# ## 03 Normalise feature data

# %%
# Out:
# Correlation matrix betwen feature variables
# <style  type="text/css" >
#     #T_800c3192_29cb_11eb_b37b_645aede888e3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_800c3192_29cb_11eb_b37b_645aede888e3row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_800c3192_29cb_11eb_b37b_645aede888e3row0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_800c3192_29cb_11eb_b37b_645aede888e3row0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_800c3192_29cb_11eb_b37b_645aede888e3row0_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_800c3192_29cb_11eb_b37b_645aede888e3row0_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_800c3192_29cb_11eb_b37b_645aede888e3row0_col6 {
# ...
