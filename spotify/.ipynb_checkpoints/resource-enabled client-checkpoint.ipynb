# %%
import requests
import datetime
import base64
from urllib.parse import urlencode

# %%
client_id = 
client_secret =

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expure = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        '''
        Returns a base64 encoded string.
        '''
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception('You must set client_id and client_secret')
        client_creds = f'{client_id}:{client_secret}'
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            'Authorization': f'Basic {client_creds_b64}'
        }
    
    def get_token_data(self):
        return {
            'grant_type': 'client_credentials'
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception('Count not authenticate client')
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type='artist'):
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        lookup_url = f'{endpoint}?{data}'
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search('Bulls on parade', search_type = 'track')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Bulls+on+parade&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#        'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#        'id': '2d0hyoQ5ynDBnkvAbJKORj',
#        'name': 'Rage Against The Machine',
#        'type': 'artist',
#        'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/24E6rDvGDuYFjlGewp4ntF'},
#      'href': 'https://api.spotify.com/v1/albums/24E6rDvGDuYFjlGewp4ntF',
#      'id': '24E6rDvGDuYFjlGewp4ntF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273053f006079bce979e5fef1e1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02053f006079bce979e5fef1e1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851053f006079bce979e5fef1e1',
#        'width': 64}],
#      'name': 'Evil Empire',
#      'release_date': '1996-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:24E6rDvGDuYFjlGewp4ntF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#       'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#       'id': '2d0hyoQ5ynDBnkvAbJKORj',
#       'name': 'Rage Against The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 229466,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM19502563'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0tZ3mElWcr74OOhKEiNz1x'},
#     'href': 'https://api.spotify.com/v1/tracks/0tZ3mElWcr74OOhKEiNz1x',
#     'id': '0tZ3mElWcr74OOhKEiNz1x',
#     'is_local': False,
#     'name': 'Bulls On Parade',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9a0a212b91ae9561473158a58852f10d91a32440?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0tZ3mElWcr74OOhKEiNz1x'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6fxyWrfmjcbj5d12gXeiNV'},
#        'href': 'https://api.spotify.com/v1/artists/6fxyWrfmjcbj5d12gXeiNV',
#        'id': '6fxyWrfmjcbj5d12gXeiNV',
#        'name': 'Denzel Curry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6fxyWrfmjcbj5d12gXeiNV'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/51QdGnlyVLQBPofWLSngZR'},
#      'href': 'https://api.spotify.com/v1/albums/51QdGnlyVLQBPofWLSngZR',
#      'id': '51QdGnlyVLQBPofWLSngZR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273df3c0a34b29f4c3f07f0fae6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02df3c0a34b29f4c3f07f0fae6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851df3c0a34b29f4c3f07f0fae6',
#        'width': 64}],
#      'name': 'Bulls on Parade (triple j Like A Version)',
#      'release_date': '2019-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:51QdGnlyVLQBPofWLSngZR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6fxyWrfmjcbj5d12gXeiNV'},
#       'href': 'https://api.spotify.com/v1/artists/6fxyWrfmjcbj5d12gXeiNV',
#       'id': '6fxyWrfmjcbj5d12gXeiNV',
#       'name': 'Denzel Curry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6fxyWrfmjcbj5d12gXeiNV'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 269686,
#     'explicit': True,
#     'external_ids': {'isrc': 'AUAB01900027'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5MybjTfYBllawRD4ZvAR9Q'},
#     'href': 'https://api.spotify.com/v1/tracks/5MybjTfYBllawRD4ZvAR9Q',
#     'id': '5MybjTfYBllawRD4ZvAR9Q',
#     'is_local': False,
#     'name': 'Bulls on Parade (triple j Like A Version)',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d8aba68ff47892b5c2470850175048fcb17e0289?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5MybjTfYBllawRD4ZvAR9Q'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#        'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#        'id': '2d0hyoQ5ynDBnkvAbJKORj',
#        'name': 'Rage Against The Machine',
#        'type': 'artist',
#        'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lexBcLuhxCaLB8LbM3JvR'},
#      'href': 'https://api.spotify.com/v1/albums/5lexBcLuhxCaLB8LbM3JvR',
#      'id': '5lexBcLuhxCaLB8LbM3JvR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27300f4f7f1c947df27a3435fdc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0200f4f7f1c947df27a3435fdc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485100f4f7f1c947df27a3435fdc',
#        'width': 64}],
#      'name': 'The Battle Of Mexico City (Live)',
#      'release_date': '2020-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5lexBcLuhxCaLB8LbM3JvR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#       'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#       'id': '2d0hyoQ5ynDBnkvAbJKORj',
#       'name': 'Rage Against The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12004830'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0t01cuDrRy8UTntCrSsy4K'},
#     'href': 'https://api.spotify.com/v1/tracks/0t01cuDrRy8UTntCrSsy4K',
#     'id': '0t01cuDrRy8UTntCrSsy4K',
#     'is_local': False,
#     'name': 'Bulls On Parade - Live, Mexico City, Mexico, October 28, 1999',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b3ccf2077c79e36818796d5f61640cd0d36fbe03?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0t01cuDrRy8UTntCrSsy4K'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#        'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#        'id': '2d0hyoQ5ynDBnkvAbJKORj',
#        'name': 'Rage Against The Machine',
#        'type': 'artist',
#        'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5tQjJRsqTVaK9NZ7Rh02en'},
#      'href': 'https://api.spotify.com/v1/albums/5tQjJRsqTVaK9NZ7Rh02en',
#      'id': '5tQjJRsqTVaK9NZ7Rh02en',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738c768929da0cf35e9a05dcd0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028c768929da0cf35e9a05dcd0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518c768929da0cf35e9a05dcd0',
#        'width': 64}],
#      'name': 'Live at the Grand Olympic Auditorium',
#      'release_date': '2003-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5tQjJRsqTVaK9NZ7Rh02en'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#       'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#       'id': '2d0hyoQ5ynDBnkvAbJKORj',
#       'name': 'Rage Against The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 317493,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10312737'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3YyUzKsTKFMPJkEvlEh8vW'},
#     'href': 'https://api.spotify.com/v1/tracks/3YyUzKsTKFMPJkEvlEh8vW',
#     'id': '3YyUzKsTKFMPJkEvlEh8vW',
#     'is_local': False,
#     'name': 'Bulls on Parade - Live at the Grand Olympic Auditorium, Los Angeles, CA - September 2000',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/94e4d6f2618a22a8e2a8863413bf032ca79a843a?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3YyUzKsTKFMPJkEvlEh8vW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31Jtwuc3XU8MypjID0ZuIm'},
#        'href': 'https://api.spotify.com/v1/artists/31Jtwuc3XU8MypjID0ZuIm',
#        'id': '31Jtwuc3XU8MypjID0ZuIm',
#        'name': 'Andrew Baena',
#        'type': 'artist',
#        'uri': 'spotify:artist:31Jtwuc3XU8MypjID0ZuIm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7tHei16hRcsEEjn6rxmPkM'},
#      'href': 'https://api.spotify.com/v1/albums/7tHei16hRcsEEjn6rxmPkM',
#      'id': '7tHei16hRcsEEjn6rxmPkM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cb5402c7be545a661aa76ec8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cb5402c7be545a661aa76ec8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cb5402c7be545a661aa76ec8',
#        'width': 64}],
#      'name': 'Bulls on Parade',
#      'release_date': '2019-11-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7tHei16hRcsEEjn6rxmPkM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31Jtwuc3XU8MypjID0ZuIm'},
#       'href': 'https://api.spotify.com/v1/artists/31Jtwuc3XU8MypjID0ZuIm',
#       'id': '31Jtwuc3XU8MypjID0ZuIm',
#       'name': 'Andrew Baena',
#       'type': 'artist',
#       'uri': 'spotify:artist:31Jtwuc3XU8MypjID0ZuIm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7567HDjus3OchzVOdkLnDX'},
#       'href': 'https://api.spotify.com/v1/artists/7567HDjus3OchzVOdkLnDX',
#       'id': '7567HDjus3OchzVOdkLnDX',
#       'name': 'Johnny Ciardullo',
#       'type': 'artist',
#       'uri': 'spotify:artist:7567HDjus3OchzVOdkLnDX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221052,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHNB1906505'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6gSfKul1glsUVY5MU7Kpgx'},
#     'href': 'https://api.spotify.com/v1/tracks/6gSfKul1glsUVY5MU7Kpgx',
#     'id': '6gSfKul1glsUVY5MU7Kpgx',
#     'is_local': False,
#     'name': 'Bulls on Parade',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9199e41ff54f14cd4fb1bc37d8ee2d899b342cd0?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6gSfKul1glsUVY5MU7Kpgx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uPlxGvXMDy9eUX7oeDei'},
#        'href': 'https://api.spotify.com/v1/artists/25uPlxGvXMDy9eUX7oeDei',
#        'id': '25uPlxGvXMDy9eUX7oeDei',
#        'name': 'Brass Against',
#        'type': 'artist',
#        'uri': 'spotify:artist:25uPlxGvXMDy9eUX7oeDei'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1913aaFRHUUj4LxxBNTw79'},
#      'href': 'https://api.spotify.com/v1/albums/1913aaFRHUUj4LxxBNTw79',
#      'id': '1913aaFRHUUj4LxxBNTw79',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732244e9ced969c4b648bc8a63',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022244e9ced969c4b648bc8a63',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512244e9ced969c4b648bc8a63',
#        'width': 64}],
#      'name': 'Brass Against',
#      'release_date': '2018-08-17',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1913aaFRHUUj4LxxBNTw79'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uPlxGvXMDy9eUX7oeDei'},
#       'href': 'https://api.spotify.com/v1/artists/25uPlxGvXMDy9eUX7oeDei',
#       'id': '25uPlxGvXMDy9eUX7oeDei',
#       'name': 'Brass Against',
#       'type': 'artist',
#       'uri': 'spotify:artist:25uPlxGvXMDy9eUX7oeDei'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZOIPu5gy4F5VFvJrRfvVP'},
#       'href': 'https://api.spotify.com/v1/artists/0ZOIPu5gy4F5VFvJrRfvVP',
#       'id': '0ZOIPu5gy4F5VFvJrRfvVP',
#       'name': 'Sophia Urista',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZOIPu5gy4F5VFvJrRfvVP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 231786,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCADT1855107'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2rTq578YnXdKSVlr0JXFJ3'},
#     'href': 'https://api.spotify.com/v1/tracks/2rTq578YnXdKSVlr0JXFJ3',
#     'id': '2rTq578YnXdKSVlr0JXFJ3',
#     'is_local': False,
#     'name': 'Bulls On Parade',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/85b0823a1ad69e37dcc23b6671055c08e6e38979?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2rTq578YnXdKSVlr0JXFJ3'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1twQEQUB9cGQJRKBIuV5zE'},
#      'href': 'https://api.spotify.com/v1/albums/1twQEQUB9cGQJRKBIuV5zE',
#      'id': '1twQEQUB9cGQJRKBIuV5zE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273250a2ee38bcf60e1e3cbdf04',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02250a2ee38bcf60e1e3cbdf04',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851250a2ee38bcf60e1e3cbdf04',
#        'width': 64}],
#      'name': "Woodstock '99",
#      'release_date': '1999-10-19',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:1twQEQUB9cGQJRKBIuV5zE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#       'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#       'id': '2d0hyoQ5ynDBnkvAbJKORj',
#       'name': 'Rage Against The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 229306,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM19911549'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50p3xSYXz8kq5rE568tQfn'},
#     'href': 'https://api.spotify.com/v1/tracks/50p3xSYXz8kq5rE568tQfn',
#     'id': '50p3xSYXz8kq5rE568tQfn',
#     'is_local': False,
#     'name': 'Bulls on Parade - Live',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d69d53165bcd240025e8896e42600bf65b5ac9be?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:50p3xSYXz8kq5rE568tQfn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6GkJh85o22LfD2vgL9DP6f'},
#        'href': 'https://api.spotify.com/v1/artists/6GkJh85o22LfD2vgL9DP6f',
#        'id': '6GkJh85o22LfD2vgL9DP6f',
#        'name': 'Dirty Heads',
#        'type': 'artist',
#        'uri': 'spotify:artist:6GkJh85o22LfD2vgL9DP6f'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4BPGOyXZzwewhnpOiikI4M'},
#      'href': 'https://api.spotify.com/v1/albums/4BPGOyXZzwewhnpOiikI4M',
#      'id': '4BPGOyXZzwewhnpOiikI4M',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a435116d29e7363a58888528',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a435116d29e7363a58888528',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a435116d29e7363a58888528',
#        'width': 64}],
#      'name': 'Home | Phantoms of Summer: The Acoustic Sessions',
#      'release_date': '2013-10-29',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4BPGOyXZzwewhnpOiikI4M'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6GkJh85o22LfD2vgL9DP6f'},
#       'href': 'https://api.spotify.com/v1/artists/6GkJh85o22LfD2vgL9DP6f',
#       'id': '6GkJh85o22LfD2vgL9DP6f',
#       'name': 'Dirty Heads',
#       'type': 'artist',
#       'uri': 'spotify:artist:6GkJh85o22LfD2vgL9DP6f'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 213382,
#     'explicit': True,
#     'external_ids': {'isrc': 'USDPK1303516'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5j0YyFRMWxtQxRKrGjvPfm'},
#     'href': 'https://api.spotify.com/v1/tracks/5j0YyFRMWxtQxRKrGjvPfm',
#     'id': '5j0YyFRMWxtQxRKrGjvPfm',
#     'is_local': False,
#     'name': "Sloth's Revenge",
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b1dd5cc4cb9c4ec37478e0da5eab65eca845b88a?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5j0YyFRMWxtQxRKrGjvPfm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5qvrAlKjc0Sqrqz6v2wBGk'},
#        'href': 'https://api.spotify.com/v1/artists/5qvrAlKjc0Sqrqz6v2wBGk',
#        'id': '5qvrAlKjc0Sqrqz6v2wBGk',
#        'name': 'JT Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:5qvrAlKjc0Sqrqz6v2wBGk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7tr3dYlDqRiQWPpEv7e2tg'},
#      'href': 'https://api.spotify.com/v1/albums/7tr3dYlDqRiQWPpEv7e2tg',
#      'id': '7tr3dYlDqRiQWPpEv7e2tg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d0014d486a04ce715c4f9585',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d0014d486a04ce715c4f9585',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d0014d486a04ce715c4f9585',
#        'width': 64}],
#      'name': 'Boots on the Ground',
#      'release_date': '2017-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7tr3dYlDqRiQWPpEv7e2tg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5qvrAlKjc0Sqrqz6v2wBGk'},
#       'href': 'https://api.spotify.com/v1/artists/5qvrAlKjc0Sqrqz6v2wBGk',
#       'id': '5qvrAlKjc0Sqrqz6v2wBGk',
#       'name': 'JT Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:5qvrAlKjc0Sqrqz6v2wBGk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 304800,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZANL1707512'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4GDhAScMDF6x8pC2QC9es0'},
#     'href': 'https://api.spotify.com/v1/tracks/4GDhAScMDF6x8pC2QC9es0',
#     'id': '4GDhAScMDF6x8pC2QC9es0',
#     'is_local': False,
#     'name': 'Boots on the Ground',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/03aebc76ebd9c0b8b42c47395309ac75eaedeb45?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4GDhAScMDF6x8pC2QC9es0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68DWke2VjdDmA75aJX5C57'},
#        'href': 'https://api.spotify.com/v1/artists/68DWke2VjdDmA75aJX5C57',
#        'id': '68DWke2VjdDmA75aJX5C57',
#        'name': 'Yelawolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:68DWke2VjdDmA75aJX5C57'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6JLpYHnehuGyPxEz79kcaF'},
#      'href': 'https://api.spotify.com/v1/albums/6JLpYHnehuGyPxEz79kcaF',
#      'id': '6JLpYHnehuGyPxEz79kcaF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739b62279a02431588835695e9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029b62279a02431588835695e9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519b62279a02431588835695e9',
#        'width': 64}],
#      'name': 'Trunk Muzik 3',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6JLpYHnehuGyPxEz79kcaF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68DWke2VjdDmA75aJX5C57'},
#       'href': 'https://api.spotify.com/v1/artists/68DWke2VjdDmA75aJX5C57',
#       'id': '68DWke2VjdDmA75aJX5C57',
#       'name': 'Yelawolf',
#       'type': 'artist',
#       'uri': 'spotify:artist:68DWke2VjdDmA75aJX5C57'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 258093,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1242745'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/10fSMtfKxHkC91fjDVHfia'},
#     'href': 'https://api.spotify.com/v1/tracks/10fSMtfKxHkC91fjDVHfia',
#     'id': '10fSMtfKxHkC91fjDVHfia',
#     'is_local': False,
#     'name': 'All The Way Up',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4990855937d069cfa4336e3fb196c0ad65838abf?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:10fSMtfKxHkC91fjDVHfia'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5qvrAlKjc0Sqrqz6v2wBGk'},
#        'href': 'https://api.spotify.com/v1/artists/5qvrAlKjc0Sqrqz6v2wBGk',
#        'id': '5qvrAlKjc0Sqrqz6v2wBGk',
#        'name': 'JT Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:5qvrAlKjc0Sqrqz6v2wBGk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2FbTHUdaQgMPVKR0mfmvvN'},
#      'href': 'https://api.spotify.com/v1/albums/2FbTHUdaQgMPVKR0mfmvvN',
#      'id': '2FbTHUdaQgMPVKR0mfmvvN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273052cdcca2d7555f4c09cfb42',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02052cdcca2d7555f4c09cfb42',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851052cdcca2d7555f4c09cfb42',
#        'width': 64}],
#      'name': 'O.P.',
#      'release_date': '2017-12-20',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:2FbTHUdaQgMPVKR0mfmvvN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5qvrAlKjc0Sqrqz6v2wBGk'},
#       'href': 'https://api.spotify.com/v1/artists/5qvrAlKjc0Sqrqz6v2wBGk',
#       'id': '5qvrAlKjc0Sqrqz6v2wBGk',
#       'name': 'JT Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:5qvrAlKjc0Sqrqz6v2wBGk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 304800,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZAPG1744939'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Bovo6xM4PXh4X6hYIzgra'},
#     'href': 'https://api.spotify.com/v1/tracks/4Bovo6xM4PXh4X6hYIzgra',
#     'id': '4Bovo6xM4PXh4X6hYIzgra',
#     'is_local': False,
#     'name': 'Boots on the Ground',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/03aebc76ebd9c0b8b42c47395309ac75eaedeb45?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:4Bovo6xM4PXh4X6hYIzgra'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6SiyKSeJo6gcsS2NvuAbsl'},
#        'href': 'https://api.spotify.com/v1/artists/6SiyKSeJo6gcsS2NvuAbsl',
#        'id': '6SiyKSeJo6gcsS2NvuAbsl',
#        'name': 'zebrahead',
#        'type': 'artist',
#        'uri': 'spotify:artist:6SiyKSeJo6gcsS2NvuAbsl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3tzvxBdYuBLvwYloAnIybs'},
#      'href': 'https://api.spotify.com/v1/albums/3tzvxBdYuBLvwYloAnIybs',
#      'id': '3tzvxBdYuBLvwYloAnIybs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273649eb4c1c4ae199132e94573',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02649eb4c1c4ae199132e94573',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851649eb4c1c4ae199132e94573',
#        'width': 64}],
# ...
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5d4mEdJuM43KpiCOAmCyiY'},
#      'href': 'https://api.spotify.com/v1/albums/5d4mEdJuM43KpiCOAmCyiY',
#      'id': '5d4mEdJuM43KpiCOAmCyiY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366acf3a0f8c3b48e1a241681',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266acf3a0f8c3b48e1a241681',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166acf3a0f8c3b48e1a241681',
#        'width': 64}],
#      'name': 'Ipecac Neat',
#      'release_date': '2005-03-16',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5d4mEdJuM43KpiCOAmCyiY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4sH7SLGP6BLOYDtcP6Lm47'},
#       'href': 'https://api.spotify.com/v1/artists/4sH7SLGP6BLOYDtcP6Lm47',
#       'id': '4sH7SLGP6BLOYDtcP6Lm47',
#       'name': 'P.O.S',
#       'type': 'artist',
#       'uri': 'spotify:artist:4sH7SLGP6BLOYDtcP6Lm47'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 193613,
#     'explicit': True,
#     'external_ids': {'isrc': 'USBWK0500199'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0IQmBdsxwkC7g2mp62F5sn'},
#     'href': 'https://api.spotify.com/v1/tracks/0IQmBdsxwkC7g2mp62F5sn',
#     'id': '0IQmBdsxwkC7g2mp62F5sn',
#     'is_local': False,
#     'name': 'I Play the Matador (redo)',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5d4ffa6dd3cb40da36bee8b1a4cf167ce8a4ab82?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0IQmBdsxwkC7g2mp62F5sn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68DWke2VjdDmA75aJX5C57'},
#        'href': 'https://api.spotify.com/v1/artists/68DWke2VjdDmA75aJX5C57',
#        'id': '68DWke2VjdDmA75aJX5C57',
#        'name': 'Yelawolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:68DWke2VjdDmA75aJX5C57'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1tav46Hvc0sQn9GWHGCKWa'},
#      'href': 'https://api.spotify.com/v1/albums/1tav46Hvc0sQn9GWHGCKWa',
#      'id': '1tav46Hvc0sQn9GWHGCKWa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273afe3d09edaa2ffd59d58c112',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02afe3d09edaa2ffd59d58c112',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851afe3d09edaa2ffd59d58c112',
#        'width': 64}],
#      'name': 'Trunk Muzik 3',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1tav46Hvc0sQn9GWHGCKWa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68DWke2VjdDmA75aJX5C57'},
#       'href': 'https://api.spotify.com/v1/artists/68DWke2VjdDmA75aJX5C57',
#       'id': '68DWke2VjdDmA75aJX5C57',
#       'name': 'Yelawolf',
#       'type': 'artist',
#       'uri': 'spotify:artist:68DWke2VjdDmA75aJX5C57'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 258093,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUYG1242762'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2upHhXNq8NcayQOAkULAiD'},
#     'href': 'https://api.spotify.com/v1/tracks/2upHhXNq8NcayQOAkULAiD',
#     'id': '2upHhXNq8NcayQOAkULAiD',
#     'is_local': False,
#     'name': 'All The Way Up',
#     'popularity': 6,
#     'preview_url': 'https://p.scdn.co/mp3-preview/070ebf99a66ad074206f63542e2b42a7010d4ebd?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:2upHhXNq8NcayQOAkULAiD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M6wiQRBBQ4asKRC5mrLm9'},
#        'href': 'https://api.spotify.com/v1/artists/6M6wiQRBBQ4asKRC5mrLm9',
#        'id': '6M6wiQRBBQ4asKRC5mrLm9',
#        'name': 'Sly deSilva',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M6wiQRBBQ4asKRC5mrLm9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2pGjjH6tsNOiMxChpZbB2U'},
#      'href': 'https://api.spotify.com/v1/albums/2pGjjH6tsNOiMxChpZbB2U',
#      'id': '2pGjjH6tsNOiMxChpZbB2U',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f4c91a4036d4d5ea9cf56c68',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f4c91a4036d4d5ea9cf56c68',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f4c91a4036d4d5ea9cf56c68',
#        'width': 64}],
#      'name': 'All-American Villain, Vol. 1',
#      'release_date': '2020-07-04',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2pGjjH6tsNOiMxChpZbB2U'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M6wiQRBBQ4asKRC5mrLm9'},
#       'href': 'https://api.spotify.com/v1/artists/6M6wiQRBBQ4asKRC5mrLm9',
#       'id': '6M6wiQRBBQ4asKRC5mrLm9',
#       'name': 'Sly deSilva',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M6wiQRBBQ4asKRC5mrLm9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196495,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAFA2057314'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2pVIUBrwLCyULpYNjRGCXN'},
#     'href': 'https://api.spotify.com/v1/tracks/2pVIUBrwLCyULpYNjRGCXN',
#     'id': '2pVIUBrwLCyULpYNjRGCXN',
#     'is_local': False,
#     'name': 'The Pledge of Allegiance',
#     'popularity': 9,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3d61fbc9cfb60bba689954c6e5179baaaacd3e8e?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2pVIUBrwLCyULpYNjRGCXN'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mGCLimuzOdod4Lnegny4d'},
#        'href': 'https://api.spotify.com/v1/artists/3mGCLimuzOdod4Lnegny4d',
#        'id': '3mGCLimuzOdod4Lnegny4d',
#        'name': 'Twinkle Twinkle Little Rock Star',
#        'type': 'artist',
#        'uri': 'spotify:artist:3mGCLimuzOdod4Lnegny4d'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4yslAA9RRunFv794tGbDMw'},
#      'href': 'https://api.spotify.com/v1/albums/4yslAA9RRunFv794tGbDMw',
#      'id': '4yslAA9RRunFv794tGbDMw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273578c93dcda8a3cf3f31e02c0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02578c93dcda8a3cf3f31e02c0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851578c93dcda8a3cf3f31e02c0',
#        'width': 64}],
#      'name': 'Lullaby Versions of Rage Against the Machine',
#      'release_date': '2015-03-16',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4yslAA9RRunFv794tGbDMw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mGCLimuzOdod4Lnegny4d'},
#       'href': 'https://api.spotify.com/v1/artists/3mGCLimuzOdod4Lnegny4d',
#       'id': '3mGCLimuzOdod4Lnegny4d',
#       'name': 'Twinkle Twinkle Little Rock Star',
#       'type': 'artist',
#       'uri': 'spotify:artist:3mGCLimuzOdod4Lnegny4d'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208474,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQY51521989'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6uzdATVo4TbxZBBqvHK0v8'},
#     'href': 'https://api.spotify.com/v1/tracks/6uzdATVo4TbxZBBqvHK0v8',
#     'id': '6uzdATVo4TbxZBBqvHK0v8',
#     'is_local': False,
#     'name': 'Bulls on Parade',
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/63bf5aa438f3e8098391b6f74f85f800394729d0?cid=f5ef4c349d99413abdd7c8b908f753d2',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6uzdATVo4TbxZBBqvHK0v8'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Bulls+on+parade&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 121}}
