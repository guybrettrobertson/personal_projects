# %% [markdown]
# # Whatsapp chat bot

# %%
def split_text(filename):
  """
  Split file contents by newline.
  """
  chat = open(filename)
  chatText = chat.read()
  return chatText.splitlines()

# %%
raw_chat = split_text('/Users/guybrett-robertson/Documents/data/whatsapp_chats/_chat.txt')

# %%
print(raw_chat[0:10])
# Out:
# ['[06/08/2016, 20:06:08] Mema Nackasha: \u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.', '[24/08/2016, 11:40:54] Mema Nackasha: What are you doing', '[24/08/2016, 11:41:07] Mema Nackasha: Were you drunk', "[24/08/2016, 12:37:58] Guy: I'm at work", "[24/08/2016, 12:38:17] Guy: Just cba'd to take a quality photo", '[24/08/2016, 15:44:02] Mema Nackasha: No I meant last night', '[24/08/2016, 15:44:21] Mema Nackasha: Pic', "[24/08/2016, 15:44:21] Mema Nackasha: You looked cute in today's pis", '[25/08/2016, 08:42:58] Guy: Thnx', '[25/08/2016, 08:43:08] Guy: Wanna come round on Saturday evening?']

# %%
n = len(raw_chat)
print(n)
# Out:
# 22719

# %%
chat = []
for i in range(n):
    row = raw_chat[i]
    if len(row) != 0:
        if row[0] == '[':
            pass
            row = row.split('] ')[1]
            row = row.split(': ')[0:2]
            print(row)
# Out:
# ['Mema Nackasha', '\u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.']
# ['Mema Nackasha', 'What are you doing']
# ['Mema Nackasha', 'Were you drunk']
# ['Guy', "I'm at work"]
# ['Guy', "Just cba'd to take a quality photo"]
# ['Mema Nackasha', 'No I meant last night']
# ['Mema Nackasha', 'Pic']
# ['Mema Nackasha', "You looked cute in today's pis"]
# ['Guy', 'Thnx']
# ['Guy', 'Wanna come round on Saturday evening?']
# ['Guy', "We're gonna go out to pubs and bars in my area"]
# ['Mema Nackasha', 'Yeah maybs baby ! Sounds good!']
# ['Mema Nackasha', 'Who else did you invite ?']
# ['Guy', 'Jake']
# ['Mema Nackasha', 'Oh I dunno if I get on well with that one']
# ['Mema Nackasha', "I'll think about it xx"]
# ['Guy', 'And Kian']
# ['Guy', 'And probs Annie']
# ['Mema Nackasha', "Don't like any of those people"]
# ['Mema Nackasha', 'Lol jk']
# ['Mema Nackasha', 'Sounds awesome']
# ['Guy', 'When are you gonna be around?']
# ['Mema Nackasha', '5 mins']
# ['Guy', 'Srsly?']
# ['Mema Nackasha', 'Find friends me']
# ['Mema Nackasha', "If you're having sex I can detour"]
# ['Guy', "No I'm not lol"]
# ['Guy', 'I see you!']
# ['Mema Nackasha', 'Am i looking cute']
# ['Guy', 'How was interview?']
# ['Guy', 'And what was it for?']
# ['Mema Nackasha', "Omg it was the most horrible experience I'm drained"]
# ['Mema Nackasha', 'It was a group interview']
# ['Guy', 'Oh lame']
# ['Mema Nackasha', 'I got it tho']
# ['Guy', 'Sorry with people']
# ['Mema Nackasha', 'It was just a horrible process']
# ['Guy', "What's the job?"]
# ['Mema Nackasha', "It's a sales recruiter so they'll call me tomorrow with jobs"]
# ['Mema Nackasha', 'Today was just the interview process']
# ['Mema Nackasha', 'Wolfestone']
# ['Mema Nackasha', "Appaz it's the best one"]
# ['Guy', 'Oh right']
# ['Mema Nackasha', 'I was in a room with 32 other people who all had a first and all spoke languages and were all bubbly']
# ['Mema Nackasha', "I was certain I wouldn't get through"]
# ['Mema Nackasha', "I'm dead it was horrible"]
# ['Guy', 'Hahaha']
# ['Guy', 'Awesome! Not even surprised 😊']
# ['Mema Nackasha', 'I am']
# ['Mema Nackasha', "I'm drained"]
# ['Guy', "How come you've done so much for sales recruiting?"]
# ['Mema Nackasha', "Because everyone I've spoken to says I have the personality for it"]
# ['Mema Nackasha', 'I did get asked in the interview if I was too nice for sales tho lols']
# ['Guy', 'Oh yeah']
# ['Guy', 'Interesting']
# ['Mema Nackasha', 'And also because I spoke to a couple of random people']
# ['Mema Nackasha', 'Randomly']
# ['Mema Nackasha', 'Who studied languages and then went into political activism']
# ['Mema Nackasha', 'And they said they wished they got a proper job first']
# ['Mema Nackasha', 'Then gone into it after r']
# ['Mema Nackasha', 'And I was like k']
# ['Guy', 'How come?']
# ['Mema Nackasha', '1 said it was because of the money']
# ['Mema Nackasha', 'And the other said it would have been nice to experience the working world properly']
# ['Mema Nackasha', 'Which is what I wanna do I guess']
# ['Mema Nackasha', 'For a bit anyway']
# ['Guy', 'Yah']
# ['Mema Nackasha', "I'm already feeling claustrophobic about not having time off to travel whenever I want now"]
# ['Mema Nackasha', "I don't like that"]
# ['Guy', "You're gonna kill it in sales"]
# ['Guy', 'Hahahaah']
# ['Guy', "That's hilar"]
# ['Mema Nackasha', 'But all the girls today were literal models']
# ['Mema Nackasha', 'Everyone was posh']
# ['Mema Nackasha', 'I was like hey yo']
# ['Guy', 'Like u']
# ['Mema Nackasha', 'Lol']
# ['Mema Nackasha', 'I felt so uncomfortable']
# ['Mema Nackasha', "And I wasn't even wearing heels cos cba"]
# ['Mema Nackasha', "So I was so certain they'd be like nah"]
# ['Mema Nackasha', 'It was so draining']
# ['Mema Nackasha', 'Bleugh']
# ['Guy', 'I would do so badly at sales']
# ['Guy', 'In other languages esp']
# ['Mema Nackasha', "But you're an astronaut doodies"]
# ['Mema Nackasha', 'Also one of the group tasks']
# ['Mema Nackasha', 'Was a list of items']
# ['Mema Nackasha', 'And we had to order them']
# ['Mema Nackasha', 'In importance']
# ['Mema Nackasha', 'Of if your rocket crashed on the moon']
# ['Mema Nackasha', "And j was like where's my astronaut 😩"]
# ['Guy', 'Hahahaah']
# ['Guy', 'I had the same thing!']
# ['Guy', 'Except it was like historical inventions']
# ['Mema Nackasha', 'Well of course you did']
# ['Mema Nackasha', 'Oh']
# ['Guy', 'Like the wheel and the Internet']
# ['Mema Nackasha', "The internet is an important one isn't it"]
# ['Guy', 'Yep']
# ['Mema Nackasha', '😩']
# ['Mema Nackasha', "I've decided I'm going to retire xx"]
# ['Guy', 'Hahahaah was it really hard']
# ['Mema Nackasha', 'Nah it was just some training']
# ['Mema Nackasha', 'But Lololol']
# ['Mema Nackasha', 'Miss u']
# ['Mema Nackasha', "I've forgotten what you look like"]
# ['Guy', 'Ready for interview?']
# ['Guy', 'Lol']
# ['Mema Nackasha', 'Kinda']
# ['Mema Nackasha', 'Me and Jake are having our first argument btw']
# ['Guy', 'Bout what?']
# ['Guy', 'Drama lama']
# ['Guy', 'How do you feel?']
# ['Guy', 'Look wha Annie made me!']
# ['Guy', 'While I was at work']
# ['Mema Nackasha', 'Omg jeal !!!']
# ['Guy', 'You and Jake have both had the same issue with one another']
# ['Mema Nackasha', "That's kind of her"]
# ['Mema Nackasha', 'And I cba BLUGH']
# ['Mema Nackasha', 'It was a real argument :(']
# ['Mema Nackasha', "We've ever argued"]
# ['Mema Nackasha', "And we didn't even fix it"]
# ['Mema Nackasha', "And I said I'm going to bed good night"]
# ['Mema Nackasha', "And we didn't fix the argument :("]
# ['Guy', "I'm sure you will"]
# ['Guy', "Don't worry"]
# ['Guy', 'Your friendship is stronger than this']
# ['Mema Nackasha', "Yes but now I'm upset"]
# ['Mema Nackasha', "He's been ignoring me since Friday"]
# ['Mema Nackasha', 'Not as a joke']
# ['Mema Nackasha', 'Like he actually was Angry at me']
# ['Guy', 'Sorry babe 😩']
# ['Guy', 'Want me to do anything about it?']
# ['Mema Nackasha', 'In even worse news, bake off is moving to channel 4 which means adverts']
# ['Mema Nackasha', "And no its ok thanks he'll probably be mad I told you"]
# ['Guy', 'Fuck adverts']
# ['Guy', 'We can probably watch it on 4od right?']
# ['Mema Nackasha', 'But that has adverts !!']
# ['Guy', 'Oh fuck this']
# ['Mema Nackasha', 'Shall I drive to his and give him a hug']
# ['Mema Nackasha', "I'm feeling so sad"]
# ['Guy', 'Up to you']
# ['Mema Nackasha', 'I did it !!!']
# ['Mema Nackasha', 'MHH']
# ['Mema Nackasha', 'All is good']
# ['Guy', 'Lol of course you did']
# ['Mema Nackasha', 'Did you snap me today']
# ['Mema Nackasha', "I'm not sure you did"]
# ['Mema Nackasha', 'Also me and bunny are so cute']
# ['Guy', 'Here you go']
# ['Mema Nackasha', 'Mmh']
# ['Guy', 'Are you doing the interview tomorrow then']
# ['Mema Nackasha', 'Yes']
# ['Guy', 'Good luck!']
# ['Guy', 'Just be yourself']
# ['Mema Nackasha', 'Merci bébé ']
# ['Guy', 'Annie says this']
# ['Guy', 'Tell Mema to be my best friend and keep me in baba ghanoush']
# ['Guy', 'I think she means ".. make me baba ghanoush" lol']
# ['Mema Nackasha', 'Hahaha cute']
# ['Mema Nackasha', "Yeah let's do one night at the flat and I'll make baba ghanoush"]
# ['Mema Nackasha', 'Fo sho']
# ['Guy', 'Awesome!']
# ['Guy', 'Would weekday or weekend be better for you?']
# ['Mema Nackasha', "I like weekdays because I don't like being in the flat alone haha"]
# ['Guy', 'Passed 1/3 exams 😖']
# ['Mema Nackasha', '😠']
# ['Mema Nackasha', "If my cleverest astronaut can't pass them then they're dumb exams wtf"]
# ['Guy', 'Yeah exactly haha']
# ['Mema Nackasha', 'R u mad or sad']
# ['Guy', '😘']
# ['Mema Nackasha', 'Congrats on the one you passed btw 😘😘😘😘😘']
# ['Guy', 'Thanks']
# ['Mema Nackasha', "I'm going to Paris tonight woo"]
# ['Guy', 'Lol']
# ['Guy', 'Send us some pics']
# ['Mema Nackasha', 'Would you come to Weybridge for new year']
# ['Mema Nackasha', "Because Jake's not doing it at his"]
# ['Mema Nackasha', "So he's thinking of getting everyone to the crown"]
# ['Mema Nackasha', 'Not my favourite idea but I just want to be with you guys basically']
# ['Mema Nackasha', 'Ok more likely going to jakes flat phewwwwww']
# ['Guy', 'Yay jakes flat is best']
# ['Mema Nackasha', 'Perfect']
# ['Mema Nackasha', 'Is Annie about?']
# ['Guy', "She's party hopping"]
# ['Mema Nackasha', 'Will she be dropping in with us?']
# ['Guy', "So she'll come to us for a bit"]
# ['Mema Nackasha', 'Ok cool beans']
# ['Mema Nackasha', "Can't wait"]
# ['Mema Nackasha', "For the last few hours jake said he wasn't having a party and that we were going to the crown and I was not happy about that"]
# ['Mema Nackasha', "I don't like the crown"]
# ['Mema Nackasha', 'So yayyyy perfect']
# ['Guy', 'Does he actually want to though?']
# ['Guy', "We shouldn't make him do it"]
# ['Guy', 'Even though he said he would weeks ago']
# ['Mema Nackasha', 'No he does']
# ['Mema Nackasha', 'Nobody is making him dw']
# ['Guy', 'Kewl']
# ['Mema Nackasha', 'Shall I come around 6ish with']
# ['Mema Nackasha', 'Or earlier or later']
# ['Mema Nackasha', 'Jakes not replying']
# ['Guy', 'Whenever you like']
# ['Guy', "I'm playing video games"]
# ['Mema Nackasha', "3 mins into my new book and I'm obsessed"]
# ['Mema Nackasha', "Let's go on a tour to North Korea ok xx"]
# ['Guy', 'Eating your cheese and biscuits cos am poor']
# ['Guy', 'Where are you going on Feb? 😊']
# ['Guy', 'In*']
# ['Mema Nackasha', 'The Phil app']
# ['Mema Nackasha', 'Philippines !!']
# ['Mema Nackasha', '£260 return :)']
# ['Mema Nackasha', 'How exciting is that']
# ['Guy', "Hahaha that's amazing?!"]
# ['Guy', 'I totally forgot haha']
# ['Mema Nackasha', 'Hahahaha']
# ['Mema Nackasha', 'I knowwwww I cannot wait !']
# ['Guy', 'How long for?']
# ['Mema Nackasha', '2 weeks']
# ['Guy', "That's awesome!"]
# ['Guy', 'lol you were loving the abs last night']
# ['Mema Nackasha', 'Course I was']
# ['Mema Nackasha', "They're ridiculous"]
# ['Mema Nackasha', 'All chubby']
# ['Guy', 'Hahah']
# ['Guy', 'Yes v chubby']
# ['Mema Nackasha', 'Little babies']
# ['Mema Nackasha', 'You were definitely not loving me loving them']
# ['Mema Nackasha', 'So funny']
# ['Mema Nackasha', 'I was so entertained hahaha']
# ['Mema Nackasha', "Also because I definitely didn't want to stop partying or go to sleep"]
# ['Guy', 'Slash you were so horny, lying between 2 solid 9s']
# ['Mema Nackasha', '10s']
# ['Mema Nackasha', 'Best looking boys on the planet']
# ['Mema Nackasha', 'Yeah fair']
# ['Mema Nackasha', "I got smashed I really didn't mean to be drunk haha"]
# ['Guy', 'Hahahaha your dad']
# ['Mema Nackasha', 'I miss the abs']
# ['Guy', 'Hahaha cheeky']
# ['Guy', 'I miss the bewbs']
# ['Mema Nackasha', 'U r']
# ['Mema Nackasha', 'Hahaha']
# ['Guy', 'Always']
# ['Mema Nackasha', 'I forgot how fun abs are']
# ['Mema Nackasha', 'Chubby abs']
# ['Guy', 'Oh shush i was curled up']
# ['Guy', "They're hard"]
# ['Mema Nackasha', 'No I mean each ab is chubby']
# ['Mema Nackasha', 'Not that you are chubby']
# ['Mema Nackasha', "You've never been chubby"]
# ['Mema Nackasha', "They're just all plump and lovely"]
# ['Mema Nackasha', 'Hahahaa']
# ['Guy', 'Same with bewbs!']
# ['Mema Nackasha', 'Yes']
# ['Guy', "Didn't get to feel yours tho!"]
# ['Mema Nackasha', "Well that's cos you didn't want to"]
# ['Mema Nackasha', 'Jake was busy touching my ass while I was feeling your abs']
# ['Guy', 'Hahahha']
# ['Mema Nackasha', 'Ridiculous tripod behaviour']
# ['Guy', "Didn't get a good chance!"]
# ['Mema Nackasha', "I'm googling abs"]
# ['Guy', 'Yeah tripod antics']
# ['Guy', '😂']
# ['Mema Nackasha', 'Hahahhahaaa']
# ['Mema Nackasha', "Well what's mine is yours"]
# ['Guy', 'You wish!']
# ['Mema Nackasha', 'Abs and traps']
# ['Mema Nackasha', '👅']
# ['Guy', "Yeah that's basically what I look like"]
# ['Guy', 'With some good lighting']
# ['Mema Nackasha', 'Yep']
# ['Guy', 'Boom']
# ['Mema Nackasha', 'Fuckin elllll']
# ['Guy', "That's on FB!"]
# ['Mema Nackasha', 'I know']
# ['Mema Nackasha', 'But']
# ['Mema Nackasha', 'Fuckin ellll']
# ['Guy', 'Hahaha 😊']
# ['Guy', 'Hahahah!']
# ['Guy', "I've shown you mine..."]
# ['Mema Nackasha', "They're huge"]
# ['Mema Nackasha', 'Looool']
# ['Guy', 'Ahaha epic!']
# ['Guy', 'Friends for lyfe']
# ['Mema Nackasha', '*best']
# ['Guy', 'Hahah that was a fun day']
# ['Guy', 'And that was an awesome cocktail!']
# ['Mema Nackasha', 'It was !!']
# ['Mema Nackasha', "You're so handsome and cute"]
# ['Mema Nackasha', 'Dawwww']
# ['Mema Nackasha', '❤❤❤❤❤❤❤😂😂']
# ['Mema Nackasha', "I've got so much love to give its tiring"]
# ['Mema Nackasha', 'Look at that little face oyyyyyy']
# ['Guy', 'Crows feet lol']
# ['Guy', "I'm gonna have such smile wrinkles when I'm older"]
# ['Mema Nackasha', "I love them so much it's the cutest thing ever"]
# ['Guy', 'Hahaha I am not cute! 😡']
# ['Mema Nackasha', 'Plus I have them too']
# ['Mema Nackasha', 'Omg so cute']
# ['Mema Nackasha', 'Edibly cute']
# ['Guy', 'Omg how much do you fancy me right now']
# ['Mema Nackasha', '100']
# ['Mema Nackasha', "It's all cos of the abs really"]
# ['Guy', 'Haha!']
# ['Guy', 'Good thing there are a bunch of pics on FB for you fap to?']
# ['Mema Nackasha', 'And maybe your face too, you do have an excellent face']
# ['Mema Nackasha', "Yeah there's enough material dw xx"]
# ['Guy', 'Too kind']
# ['Guy', 'Imagine if you Jake and I had a threesome?']
# ['Mema Nackasha', 'Nope']
# ['Mema Nackasha', 'I have thought about this yeah']
# ['Mema Nackasha', 'My dream is to marry you both']
# ['Mema Nackasha', 'And be best friends who get to live together and love you both forever and ever']
# ['Guy', 'But not for us to DP you']
# ['Guy', 'Nawwww that would be amazing']
# ['Mema Nackasha', 'And then have perfect babies with your perf genes']
# ['Mema Nackasha', 'Or maybe just adopt loads']
# ['Guy', "We're like When Harry met Sally but with tripod"]
# ['Mema Nackasha', "And then we'll have an extra big double bed like my one at home"]
# ['Mema Nackasha', 'And I can be cuddled all the time']
# ['Guy', 'Hahahahaha']
# ['Mema Nackasha', "And 2 husbands means I'll maybe get enough attention ya know I need loads of attention"]
# ['Guy', 'But we have needs too!']
# ['Mema Nackasha', 'BUT 2 penises is too many penises in one go']
# ['Mema Nackasha', "Waaaaaait what needs could you have that I couldn't cater to"]
# ['Mema Nackasha', "I'd do anything for you"]
# ['Mema Nackasha', 'I already dote on you']
# ['Mema Nackasha', 'So WHAT MORE DO YOU NEED']
# ['Guy', 'Hahahaha']
# ['Guy', 'This is such a weird fantasy']
# ['Guy', 'I love it']
# ['Mema Nackasha', 'I told jake the other day']
# ['Mema Nackasha', 'and he said "u wish"']
# ['Guy', 'Hagahaaaa']
# ['Mema Nackasha', "I mean I'm already obsessed with both of you so it'd be the best life ever"]
# ['Mema Nackasha', "We'd laugh all the time"]
# ['Mema Nackasha', 'Go on fun trips']
# ['Mema Nackasha', "I'd get to hold hands with both of you"]
# ['Mema Nackasha', "It's just an amazing dream"]
# ['Guy', 'Haaaaa']
# ['Guy', 'I think Jake and I would need side-girls']
# ['Mema Nackasha', 'FOR WHAT']
# ['Mema Nackasha', 'I HAVE ENOUGH LOVE FOR YOU ☹️☹️']
# ['Guy', 'For BJs and stuff!!']
# ['Mema Nackasha', "Mate I'll remember how to do that shit and we'll all be fine"]
# ['Mema Nackasha', "Too much I'm dying"]
# ['Guy', 'Hahahaaa']
# ['Mema Nackasha', "We'd have a puppy and it'd be the only other thing you'd love as much as me"]
# ['Guy', 'Yes an Italian greyhound perhaps!']
# ['Mema Nackasha', "We'd call him Zeus but I'd call him zoozoo"]
# ['Mema Nackasha', "And we'd live in Regent's Park and brunch on the weekends and everyone would know us as the unconventional triple (couple) who live the most perfect lives together"]
# ['Mema Nackasha', "Nobody loves me as much as you 2 do, I was telling jake this, I feel so safe and loved and even sexy and smart and beautiful and lovely and nice because you've both empowered me so much"]
# ['Mema Nackasha', 'So']
# ['Mema Nackasha', "That's the dream"]
# ['Guy', 'Good!']
# ['Guy', 'You are all of those things']
# ['Guy', 'FOr some reason the other day I was thinking about what would happen if you died']
# ['Guy', 'And I reckon like 900 people would come to your funeral']
# ['Guy', 'And it would be so much worse than anyone else I know dying']
# ['Guy', 'From a general perspective']
# ['Mema Nackasha', "Omg you kill me seriously you're the best human ever"]
# ['Mema Nackasha', "Well if you died that'd be the end of my life"]
# ['Mema Nackasha', 'So']
# ['Mema Nackasha', "Don't die"]
# ['Mema Nackasha', 'Also']
# ['Guy', "Ok let's all not die"]
# ['Guy', "Haha you love backs don't you"]
# ['Mema Nackasha', 'Yes :D']
# ['Mema Nackasha', "I haven't fancied you for ages"]
# ['Mema Nackasha', 'I forgot how hot you are']
# ['Mema Nackasha', 'But']
# ['Guy', 'Hahahaha']
# ['Mema Nackasha', 'Why were you thinking of me dying']
# ['Mema Nackasha', 'Did you get sad at the thought']
# ['Guy', 'I got so sad']
# ['Guy', 'It would actually be so worse']
# ['Guy', 'Just thinking of the sheer number of people who would be devastated']
# ['Guy', 'Like 100 of your family members']
# ['Guy', 'Your priest']
# ['Guy', 'Friends in about 8 different countries']
# ['Guy', 'And companies thatyouve worked for']
# ['Guy', 'Etc']
# ['Mema Nackasha', '😱']
# ['Mema Nackasha', '😳']
# ['Guy', "And you're only 24"]
# ['Mema Nackasha', "I don't understand why and how you and jake see me as this lil angel"]
# ['Mema Nackasha', 'I feel so so special']
# ['Mema Nackasha', 'Like a rare gem']
# ['Mema Nackasha', "But I'm just another drop in the ocean"]
# ['Guy', "Everyone thinks you're a little angel"]
# ['Mema Nackasha', 'Another normal human with people who love her']
# ['Mema Nackasha', 'Like all the other people']
# ['Guy', "We're just the only ones who you care to be with"]
# ['Mema Nackasha', "I like lots of my other friends too but I'm just always happiest when my babies are around"]
# ['Guy', "We're not babies!"]
# ['Mema Nackasha', 'My babes ❤']
# ['Guy', "Let's get back to you fancying me"]
# ['Mema Nackasha', "Hahaha it's well fun"]
# ['Mema Nackasha', 'I fancied jake a bit on Thursday evening']
# ['Mema Nackasha', 'And now you tonight']
# ['Guy', "You're so flippant lol"]
# ['Mema Nackasha', "That's my middle name"]
# ['Mema Nackasha', "It's mental"]
# ['Guy', 'Want me to send you another pic']
# ['Mema Nackasha', 'YES']
# ['Mema Nackasha', '😄']
# ['Mema Nackasha', 'Yalla']
# ['Guy', "Sorry couldn't find the one I was looking for"]
# ['Guy', 'It was super sexy']
# ['Mema Nackasha', '😩']
# ['Mema Nackasha', "I'm so far down on your Facebook I think I need to stop"]
# ['Mema Nackasha', "You're a bit young for me down there"]
# ['Guy', 'Imagine if I just sent you a dick pic hahaha']
# ['Guy', 'Would be so rood']
# ['Mema Nackasha', 'Ahahhahahaaa']
# ['Guy', 'Like yeah so sexy']
# ['Mema Nackasha', "I feel like we have no boundaries so I wouldn't mind"]
# ['Guy', 'Yeah 😂']
# ['Mema Nackasha', "You and Jake can't ever do any wrong"]
# ['Mema Nackasha', 'So whatever happens is fine with me pmsl']
# ['Guy', "That's the safe for work version"]
# ['Mema Nackasha', 'Fuuuuuuuck']
# ['Mema Nackasha', "You're like Jesus but real"]
# ['Guy', 'Hahahaha']
# ['Mema Nackasha', "I think I've decided"]
# ['Mema Nackasha', 'For my bday']
# ['Mema Nackasha', "I'm gonna take the tripod on a lil trip"]
# ['Mema Nackasha', 'Or forward slash next year for our 10 year anniversary maybe']
# ['Guy', 'Cool!']
# ['Guy', 'Where to?']
# ['Mema Nackasha', 'Maybe Malta']
# ['Guy', 'Interesting']
# ['Guy', 'I have friends in Malta']
# ['Guy', 'Well, friend']
# ['Mema Nackasha', "It needs to be somewhere I've never been and I've never been there"]
# ['Mema Nackasha', 'Or Slovenia']
# ['Mema Nackasha', 'Lake bled']
# ['Mema Nackasha', "It'll be amazing"]
# ['Guy', 'Awesome!']
# ['Guy', 'Excited already']
# ['Mema Nackasha', 'Me too']
# ['Mema Nackasha', 'Maybe we could take a couple of days off in like July and do a super long weekend']
# ['Mema Nackasha', "I'll think about t"]
# ['Guy', 'I could do that']
# ['Mema Nackasha', '😊']
# ['Guy', 'Are you gonna propose to us?']
# ['Mema Nackasha', 'This is all only so that I get to see those abs in trunks']
# ['Mema Nackasha', 'Well you ruined it now']
# ['Guy', 'Omg if you want to see more just ask']
# ['Guy', "If Jake weren't there I definitely would have been tempted last night"]
# ['Mema Nackasha', 'Omg stop']
# ['Mema Nackasha', 'I forgot about abs']
# ['Mema Nackasha', 'I stopped liking them for ages']
# ['Mema Nackasha', 'But now']
# ['Mema Nackasha', 'They were in my hands and I loved them again']
# ['Guy', 'Another minute and you would have got me hard AF as well']
# ['Mema Nackasha', 'REALLY']
# ['Mema Nackasha', 'I thought you were just batting me off cos I was being annoying']
# ['Guy', 'Hahahaha']
# ['Guy', 'Nahh']
# ['Guy', 'I am human']
# ['Mema Nackasha', 'Look like a god to me']
# ['Guy', 'You want moar doncha']
# ['Mema Nackasha', 'Yes']
# ['Mema Nackasha', 'This is my favourite topic']
# ['Mema Nackasha', 'Of the evening']
# ['Mema Nackasha', "Guy's abs"]
# ['Guy', 'Hahaha tomorrow youll have forgotten']
# ['Mema Nackasha', "When we get married they'll also be mine 🤔"]
# ['Mema Nackasha', 'Yeah probs']
# ['Mema Nackasha', "I'll go back to fancying ash at work"]
# ['Mema Nackasha', 'Or maybe my gf 🙄']
# ['Guy', 'Hahaha']
# ['Guy', "Good thing we weren't alone last night then"]
# ['Mema Nackasha', 'Are you in an open relationship guygeous ?']
# ['Guy', 'You wish']
# ['Mema Nackasha', 'Just out of interest']
# ['Guy', 'No']
# ['Mema Nackasha', "I mean I don't care cos I can have you WHENEVER I WANT"]
# ['Mema Nackasha', 'Jk jk']
# ['Guy', "Which is one of the reasons why it's a good thing we weren't alone last night"]
# ['Mema Nackasha', '👅']
# ['Mema Nackasha', 'Pmsl']
# ['Mema Nackasha', "I've sent that tongue emoji a million times today"]
# ['Guy', 'Hahaha to whom else??']
# ['Mema Nackasha', 'U']
# ['Guy', 'Flirt']
# ['Mema Nackasha', 'With your abs']
# ['Mema Nackasha', '👅👅👅👅👅']
# ['Mema Nackasha', "I don't flirt"]
# ['Guy', 'Sure']
# ['Mema Nackasha', "I don't know how to"]
# ['Mema Nackasha', "I'm just nice"]
# ['Guy', 'Yeah me too']
# ['Guy', "But I'm not even nice"]
# ['Mema Nackasha', "No you're motherfucking charming as fuck"]
# ['Mema Nackasha', 'I was telling jake that']
# ['Mema Nackasha', 'Jake makes me feel like the sexiest girl on the planet without even saying anything']
# ['Mema Nackasha', "And you're so charming that you say things that melt me all the time"]
# ['Guy', 'Nawwww']
# ['Guy', "I'm definitely not charming with anyone else"]
# ['Guy', 'Seriously haha']
# ['Mema Nackasha', "We talked about it as we walked through Regent's Park"]
# ['Mema Nackasha', "I don't believe that !!!"]
# ['Mema Nackasha', "When we were at school I remember people like Zoe Lewin etc asking me what I'd done to you because you apparently had this massive soft spot for me"]
# ['Mema Nackasha', 'But everyone liked you and fancied you']
# ['Guy', "For reals, I'm only a bit charming with friends"]
# ['Mema Nackasha', 'So I assumed that you must be the same with everyone']
# ['Guy', 'Hahaha Mema']
# ['Mema Nackasha', "But since we've grown up you have so many people who adore you"]
# ['Mema Nackasha', "So I asssumeeeee you're pretty charming with them too"]
# ['Guy', "I get so little attention from women, it's always been such a shock when you say this stuff"]
# ['Guy', "It's so nice"]
# ['Mema Nackasha', "E.g. Your uni mates, like I'm sure you're the same with Lottie for example"]
# ['Guy', "Yeah that's true, with my girls from uni"]
# ['Mema Nackasha', 'See, you empower us']
# ['Mema Nackasha', "And cos you're such a genuinely amazing person"]
# ['Mema Nackasha', 'Clever and sweet AND handsome']
# ['Mema Nackasha', "It's extra amazing that lovely things come from you"]
# ['Guy', 'Thank you 😘']
# ['Mema Nackasha', "And you don't get little attention, you probably just dont realise the attention you get"]
# ['Guy', "I'm actually really insecure about women"]
# ['Guy', "And it's gotten worse as I've gotten older"]
# ['Mema Nackasha', 'For example, on the train rach said "Mema\'s boys are the nicest guys ever, plus guy is really fit" and then lowri said "yeah I thought that when I met him, but I fancy jake now"']
# ['Mema Nackasha', 'So like']
# ['Mema Nackasha', "That's hot girls fancying you"]
# ['Mema Nackasha', "I don't know how you could possibly be insecure about women, you're so desirable, every tiny bit of you is derivable"]
# ['Mema Nackasha', 'Desirable']
# ['Mema Nackasha', 'lol derivable']
# ['Mema Nackasha', 'Wish I was next to you I wanna give you a cuddle now (and not just for the abs)']
# ['Mema Nackasha', 'WHERE HAVE YOU GONE']
# ['Guy', 'Sorry getting ready for bed']
# ['Guy', 'Getting naked etc']
# ['Guy', 'Basically I can pinpoint the issue']
# ['Guy', 'After many years of thinking about it']
# ['Mema Nackasha', 'Stay naked']
# ['Mema Nackasha', 'And tell me what it is']
# ['Guy', 'Women are just too subtle']
# ['Guy', 'And they want the guy to make the first move']
# ['Guy', "And they're so stand offish that they wouldn't even smile in the street to me"]
# ['Guy', 'Like I can count how many times a stranger woman smiled at me']
# ['Guy', '3 times']
# ['Guy', 'I remember them specifically haha']
# ['Guy', 'How sad is that']
# ['Mema Nackasha', "you don't remember me !!!!"]
# ['Mema Nackasha', 'Well']
# ['Mema Nackasha', 'Nobody smiles in London']
# ['Guy', 'Yeah I missed that!']
# ['Guy', 'Hahaha']
# ['Mema Nackasha', 'I smile at everyone']
# ['Mema Nackasha', 'The big issue man on a Monday morning called out']
# ['Guy', "So yeah I guess you must think I'm a bit like Rachel"]
# ['Guy', "Hahaha that's a nice story 😊"]
# ['Guy', "You're the nicest"]
# ['Mema Nackasha', 'Women are subtle and do want men to make the first move buuuuut are you scared of getting knocked back?']
# ['Mema Nackasha', "Yeah you're literally a god"]
# ['Mema Nackasha', 'Every aspect of you']
# ['Mema Nackasha', 'So I cannot understand how you could feel insecure ever']
# ['Guy', "Well it's not necessarily like I want to actually chat someone up and go on a date"]
# ['Guy', "It's more like, I just want SOMETHING"]
# ['Mema Nackasha', "I used to be insecure but because of you and jake I don't really care about my insecurities anymore, nice work 😘😘😘😘"]
# ['Guy', 'Some affection, some sign that they actually see me']
# ['Mema Nackasha', 'Hmmmmmm']
# ['Mema Nackasha', 'Owwwww']
# ['Mema Nackasha', "That's the saddest thing you've ever said"]
# ['Mema Nackasha', "But you're a head turner like you are very gorgeous"]
# ['Guy', "Yeah and it's getting worse as I get older"]
# ['Mema Nackasha', 'How !!!!']
# ['Guy', 'Just']
# ['Mema Nackasha', "You've gotten way better as you've got older"]
# ['Mema Nackasha', "You're like wine"]
# ['Guy', "Like I'm not more attractive than I was 5 years ago"]
# ['Guy', 'Hahaha']
# ['Mema Nackasha', "You're the same attractiveness"]
# ['Mema Nackasha', "But you're nicer I think"]
# ['Guy', 'I hope so!']
# ['Mema Nackasha', "I think you've blossomed into being a perfect human"]
# ['Guy', "Anyway thanks, you don't want to hear this lol"]
# ['Mema Nackasha', 'Like you were already perfect']
# ['Mema Nackasha', "But now you're extra nice too"]
# ['Mema Nackasha', "Wait why don't I want to hear this ???"]
# ['Guy', 'Negative Nancy !']
# ['Mema Nackasha', "You're not negative"]
# ['Mema Nackasha', "You're a ray of sunshine"]
# ['Mema Nackasha', "You're allowed to feel down about one thing one time"]
# ['Mema Nackasha', "Don't be hard on yourself silly billy"]
# ['Mema Nackasha', "Plus I'm whiney 109272622 times a week and you just maintain my high maintenance self and do it very well too"]
# ['Guy', 'Hahaha']
# ['Guy', "I don't even do anything"]
# ['Mema Nackasha', '😘']
# ['Mema Nackasha', 'I dunno you do lots for me']
# ['Guy', 'Well gud']
# ['Mema Nackasha', 'I feel like everyone seems to be in relationships now']
# ['Mema Nackasha', 'And people like search for the person they want, like their ideal human, via dating apps and websites and stuff']
# ['Mema Nackasha', 'And then maybe forget to be nice to all the humans irl']
# ['Mema Nackasha', 'I mean I smile and everyone and nobody ever smiles back at me']
# ['Mema Nackasha', "But I don't really mind"]
# ['Mema Nackasha', 'Just for you to gauge you know']
# ['Guy', 'Yeah']
# ['Mema Nackasha', "Like it's easy to smile back at someone"]
# ['Guy', 'Thanks bbs']
# ['Mema Nackasha', "But people don't"]
# ['Mema Nackasha', 'I always get taken aback when someone does']
# ['Mema Nackasha', 'Haha']
# ['Guy', 'That is rood']
# ['Mema Nackasha', 'London commuters ffs']
# ['Mema Nackasha', 'It is !!']
# ['Guy', 'Yep!']
# ['Mema Nackasha', 'Anyway you always have a girlfriend']
# ['Mema Nackasha', "You're always on the market for 2.6 minutes before someone snatches you right up"]
# ['Guy', 'Yep']
# ['Guy', "I kind of don't want a girlfriend"]
# ['Guy', 'And I do']
# ['Guy', 'I want both']
# ['Mema Nackasha', 'ME TOO']
# ['Mema Nackasha', 'Omfg']
# ['Mema Nackasha', "I don't want to be in a relationship"]
# ['Mema Nackasha', 'But I want constant attention and security and love']
# ['Mema Nackasha', 'I.e. A partner']
# ['Guy', "Glad I'm not the only one"]
# ['Guy', 'Haha!']
# ['Mema Nackasha', 'THIS IS WHY I FEEL LIKE IM GONNA DIE ALONE']
# ['Mema Nackasha', 'because I change my mind so much']
# ['Mema Nackasha', "You're not flippant like me though guy"]
# ['Mema Nackasha', "You're stable and wonderful"]
# ['Guy', "You're gonna find someone who constantly surprises you"]
# ['Guy', 'And who you really worship']
# ['Guy', 'I reckon']
# ['Mema Nackasha', 'I worship everyone']
# ['Mema Nackasha', 'I worship you !!!!']
# ['Mema Nackasha', 'And jakey']
# ['Mema Nackasha', "Hence why I'm gonna marry you both"]
# ['Mema Nackasha', 'Ok']
# ['Guy', 'Yeah someone great like us']
# ['Mema Nackasha', 'Or maybe just you xx']
# ['Mema Nackasha', 'Why do you have to be 2 people']
# ['Mema Nackasha', 'How annoying for me']
# ['Guy', 'Haaaaa']
# ['Guy', 'Twopod']
# ['Mema Nackasha', '😄']
# ['Mema Nackasha', 'Hahahaa']
# ['Mema Nackasha', 'Is Annie the one']
# ['Guy', 'No']
# ['Guy', 'But I do really like her']
# ['Mema Nackasha', 'Are you in love']
# ['Guy', 'Yes']
# ['Mema Nackasha', '😊']
# ['Guy', "But she's going to law school and stuff"]
# ['Mema Nackasha', 'But if she was in London for good']
# ['Mema Nackasha', 'Could she be the one']
# ['Guy', "I don't really think so"]
# ['Mema Nackasha', "It's crazy cos I feel like she isn't either"]
# ['Mema Nackasha', "Also I feel like marie isn't my one"]
# ['Mema Nackasha', "We're in similar boats atm I think"]
# ['Guy', 'Also I don\'t really believe in "the one"']
# ['Mema Nackasha', "No that's dumb"]
# ['Mema Nackasha', 'But I mean I think you can be with someone and feel like you could happily be with them forever']
# ['Mema Nackasha', 'And there are other ones, who are just the one for now']
# ['Mema Nackasha', 'Still wanna cuddle you']
# ['Mema Nackasha', 'mate']
# ['Guy', 'Yeah I get you']
# ['Mema Nackasha', 'Gala removed me on fb']
# ['Mema Nackasha', 'Looool']
# ['Mema Nackasha', 'I thought she kind of liked me !!!!']
# ['Guy', "Hahah I haven't been friends with her for a while"]
# ['Mema Nackasha', 'Did she remove you?']
# ['Guy', 'Yeah. I probably came up on your profile']
# ['Guy', 'Gala and I had such a flawed relationship, but I loved her more intensely than anyone']
# ['Guy', 'Like the intensity of emotion was like triple what I ever feel about anything now']
# ['Guy', 'Even Guido']
# ['Guy', 'Also more than with Kathryn']
# ['Mema Nackasha', 'The whole time ???']
# ['Mema Nackasha', 'Even guido omg I love you']
# ['Mema Nackasha', "I mean, didn't the intensity die down after a year or so?"]
# ['Mema Nackasha', 'I hope you find that intensity again guygeous']
# ['Mema Nackasha', "But you know it's only because painful love feels stronger than good love"]
# ['Mema Nackasha', 'I think']
# ['Mema Nackasha', "Wish you'd been with me and jake all week, we talked about this too haha"]
# ['Guy', 'It did die down yeah']
# ['Guy', "But it's like"]
# ['Guy', 'If I i through the rest of my life not feeling that again']
# ['Guy', "I'll be seriously disappointed"]
# ['Guy', 'If I go*']
# ['Mema Nackasha', "You're still young"]
# ['Mema Nackasha', "You'll feel it again"]
# ['Guy', 'Hope so']
# ['Mema Nackasha', 'But it was pain']
# ['Mema Nackasha', "If you have a spare evening this week (I don't think that exists in your life) then I wanna come over and cuddle you"]
# ['Mema Nackasha', "I feel like I haven't looked after you much"]
# ['Mema Nackasha', 'My little babe']
# ['Guy', 'Hahah okie']
# ['Guy', "You just wanna see the abs don't you"]
# ['Mema Nackasha', '*touch']
# ['Guy', 'And more']
# ['Guy', '💦']
# ['Mema Nackasha', 'Pmsl']
# ['Mema Nackasha', "You're getting way too excited sir"]
# ['Mema Nackasha', 'I just wanna hold those chubby abs']
# ['Mema Nackasha', 'Also']
# ['Mema Nackasha', "You're huge"]
# ['Mema Nackasha', 'So is jake']
# ['Mema Nackasha', "So it's so nice to be cuddled hahaa"]
# ['Guy', 'Nawwww']
# ['Guy', 'She is lovely 😊']
# ['Mema Nackasha', "Love her so much she's my favourite female friend"]
# ['Mema Nackasha', 'Back to you']
# ['Guy', 'Enough of me']
# ['Mema Nackasha', 'Hahahaha']
# ['Mema Nackasha', "There's so much of you"]
# ['Mema Nackasha', '👅👅👅']
# ['Mema Nackasha', '😂😂😂']
# ['Mema Nackasha', 'I should be put down']
# ['Guy', '👅 💦']
# ['Mema Nackasha', 'Hehehe']
# ['Mema Nackasha', "But I can't die"]
# ['Mema Nackasha', 'Remember you have to carry my coffin']
# ['Guy', 'Yes I remember']
# ['Guy', 'How detailed is your will?']
# ['Guy', 'Or whatever those instructions are?']
# ['Mema Nackasha', 'I need to rewrite it']
# ['Mema Nackasha', 'I wrote the instructions before I went to uni']
# ['Mema Nackasha', 'Like in my gap year or something']
# ['Mema Nackasha', 'But then my laptop died']
# ['Mema Nackasha', "And my dad's friend unpicked all my info off of it"]
# ['Mema Nackasha', 'And interpreted the "if I\'m dead" as a suicide note lols oops']
# ['Mema Nackasha', "But I was pretty in love with you back then except I think it was the time we werent really friends pmsl so I can imagine it's some quick cringe note for you"]
# ['Mema Nackasha', 'I mean I had a little paragraph for all the people I loved']
# ['Mema Nackasha', 'But']
# ['Mema Nackasha', 'Those people have changed']
# ['Mema Nackasha', 'For example at the time I was so close to Ross and James and the year above boys']
# ['Guy', 'What do the paragraphs say?']
# ['Guy', 'Oh yeah!']
# ['Mema Nackasha', "Who I now haven't spoken to for years and years"]
# ['Mema Nackasha', "I can't really remember"]
# ['Mema Nackasha', "It'd just be like a mini thank you"]
# ['Mema Nackasha', 'Also instructions were who should carry my coffin']
# ['Mema Nackasha', 'And that whatever you do with me, bunny must come with me']
# ['Mema Nackasha', "Don't even know if I still have it"]
# ['Guy', 'Haaaa']
# ['Guy', 'That is funny']
# ['Guy', 'And morbid']
# ['Mema Nackasha', "Well I'm just always scared of leaving people I love"]
# ['Mema Nackasha', "I'm not scared of dying"]
# ['Mema Nackasha', "But I'm scared of what'll happen to my closest humans"]
# ['Mema Nackasha', 'I dunno']
# ['Mema Nackasha', "I don't think about it anymore"]
# ['Mema Nackasha', 'But I always used to worry about it']
# ['Guy', "You're sweet"]
# ['Guy', 'Too sweet!']
# ['Mema Nackasha', 'You are']
# ['Mema Nackasha', 'I need to do my will']
# ['Mema Nackasha', 'Atm it just says give everything to Lolo']
# ['Guy', 'Which is probably good no?']
# ['Mema Nackasha', 'Yes but what if he dies with me']
# ['Mema Nackasha', 'I want some details']
# ['Mema Nackasha', "If my family die I'll leave you and Jake most of the rest of my things"]
# ['Mema Nackasha', "I'll actually maybe just leaving you my savings account to pay off that stupid astronaut loan"]
# ['Mema Nackasha', "I'll make a note I need to do that"]
# ['Mema Nackasha', 'Write my will properly']
# ['Guy', 'Hmmm so now I just have to take care of Louis and you']
# ['Guy', 'Lewis']
# ['Guy', 'Lewie']
# ['Mema Nackasha', ':)']
# ['Guy', 'And Jake']
# ['Mema Nackasha', "I'll leave him some things too"]
# ['Mema Nackasha', "That's why I'm gonna take us away"]
# ['Mema Nackasha', 'May as well enjoy the money with you guys']
# ['Guy', 'Woo!']
# ['Mema Nackasha', "Rather than dying and then you'd be too depressed to go to Slovenia without me"]
# ['Mema Nackasha', 'Hahahaa']
# ['Guy', "You're not gonna die for like 65 years"]
# ['Mema Nackasha', "I literally feel like I'll be the oldest person in the world one day"]
# ['Mema Nackasha', 'I feel like that']
# ['Mema Nackasha', "Do you feel like you'll live till you're old"]
# ['Guy', 'No']
# ['Mema Nackasha', 'Love you']
# ['Guy', 'Love you too 😘']
# ['Mema Nackasha', '😘😘😘😘😘']
# ['Guy', 'Are you done fancying me now?']
# ['Mema Nackasha', 'Yep']
# ['Mema Nackasha', 'Actually']
# ['Mema Nackasha', "I just looked at our media on whatsapp and it's all abs"]
# ['Mema Nackasha', 'Hahaha']
# ['Mema Nackasha', 'The tripod has had such an incestual week']
# ['Guy', 'Hahaha!']
# ['Mema Nackasha', '😘😘😘😘']
# ['Mema Nackasha', '"It\'s difficult to hate you because you\'re so bloody nice" ']
# ['Mema Nackasha', "-Mema's colleagues 2k17"]
# ['Mema Nackasha', '😂😂😂']
# ['Guy', 'Hahahahaha']
# ['Mema Nackasha', 'JAKE IS GOING FOR A DRINK WITH EVA THIS WEEKEND !!!']
# ['Mema Nackasha', 'Maybe']
# ['Mema Nackasha', 'SATURDAY NIGHT']
# ['Guy', 'Busy Saturday night']
# ['Guy', 'Free on Friday like we already planned!']
# ['Guy', 'Hahaha']
# ['Guy', 'Oh right']
# ['Guy', 'Yeah!']
# ['Mema Nackasha', 'Have you heard what happened to jake']
# ['Mema Nackasha', 'He might not come tonight looool']
# ['Guy', 'No?!']
# ['Guy', 'Too many chillis?']
# ['Mema Nackasha', 'He did the chilli challenge']
# ['Mema Nackasha', "Didn't make it to work"]
# ['Mema Nackasha', "Cos he's fucked his tummy up"]
# ['Guy', 'Ohhhh shiiiiitttttt']
# ['Guy', 'Is he ok??']
# ['Mema Nackasha', 'I think so']
# ['Mema Nackasha', "But he's in pain"]
# ['Guy', 'So is it just me coming tonight?']
# ['Mema Nackasha', 'Sam and Luke']
# ['Mema Nackasha', 'And lowri']
# ['Mema Nackasha', 'Miri and her mate']
# ['Mema Nackasha', 'And I think jake will come']
# ['Guy', 'Oh right!! I thog it it was just tripod']
# ['Mema Nackasha', 'I invited you guys specifically']
# ['Mema Nackasha', 'Because']
# ['Mema Nackasha', 'Lowri asked to stay at mine for the weekend']
# ['Mema Nackasha', "and I didn't really fancy being alone with her"]
# ['Mema Nackasha', "So then I invited rach but she cancelled last night as she's working lates"]
# ['Mema Nackasha', 'But I asked you and jake to come because I love you most']
# ['Mema Nackasha', "And then Sam was really gutted he missed out on rach's bday so I invited him"]
# ['Mema Nackasha', 'And he asked if Luke could come']
# ['Mema Nackasha', 'So I was like fuck it']
# ['Mema Nackasha', 'Everyone can come whatever']
# ['Mema Nackasha', "But it's not a party"]
# ['Mema Nackasha', "Eva hasn't replied to jake 🤔"]
# ['Guy', 'Oh no!!']
# ['Guy', 'Is he still at home or is he waiting for her out??']
# ['Mema Nackasha', "He's at home"]
# ['Mema Nackasha', 'He text her at 4.30 saying shall we meet at 8']
# ['Mema Nackasha', "And he wasn't sure if the message delivered"]
# ['Mema Nackasha', 'She was on whatsapp at 6.30']
# ['Guy', 'Do you think I should text her or anything?']
# ['Mema Nackasha', "So he whatsapped her saying I don't know if my messages have delivered"]
# ['Mema Nackasha', "And he hasn't heard anything still"]
# ['Mema Nackasha', 'Maybe not just yet']
# ['Guy', "That's annoying"]
# ['Mema Nackasha', "Let's wait till 8.30"]
# ['Mema Nackasha', "Yeah it's"]
# ['Mema Nackasha', 'However he did leave it quite late']
# ['Mema Nackasha', 'But still']
# ['Guy', 'I like Eva']
# ['Mema Nackasha', 'Me too']
# ['Mema Nackasha', 'But I feel a but coming along']
# ['Guy', "But I have a feeling she's not the kind of person who I want me friends to be with"]
# ['Guy', 'For their sakes']
# ['Guy', 'Based on some of the things Annie has told me']
# ['Guy', "But I'm not sure about that"]
# ['Mema Nackasha', 'Hmm']
# ['Mema Nackasha', 'Well']
# ['Mema Nackasha', 'If she messes jake around I will be very angry']
# ['Guy', 'Yeah me too']
# ['Mema Nackasha', 'Love u']
# ['Mema Nackasha', "also thank you for my prosecco and toblerone you're really my fave"]
# ['Mema Nackasha', '(Marginally)']
# ['Guy', 'Hahaha']
# ['Mema Nackasha', 'Still nothing']
# ['Mema Nackasha', 'Should he call her']
# ['Guy', "Urgh that's so rood of her"]
# ['Mema Nackasha', '☹️']
# ['Mema Nackasha', 'SO ROOD']
# ['Guy', 'Did you mean to write that in tripod']
# ['Mema Nackasha', 'Yes']
# ['Mema Nackasha', 'I told him we need to discuss things with you']
# ['Mema Nackasha', 'As you know her']
# ['Mema Nackasha', 'Btw please think again about me giving u the monies']
# ['Mema Nackasha', 'We did it last time and it worked really well I thought']
# ['Mema Nackasha', "And I'd love to help you out"]
# ['Mema Nackasha', "And it wouldn't effect me in the slightest"]
# ['Mema Nackasha', 'And just think about it']
# ['Mema Nackasha', "I'll keep offering"]
# ['Guy', 'Thanks']
# ['Guy', "But I was telling you so you'd understand when I don't come to some events"]
# ['Mema Nackasha', 'I understand baby boy']
# ['Mema Nackasha', "But also understand that like I'd do anything for Lolo, the same applies for you"]
# ['Mema Nackasha', "I'd give you allllllll my monies if you needed them"]
# ['Mema Nackasha', "And also I'd rather you have fun and don't be stressed about money when I can help out"]
# ['Guy', 'Srsly what was up with Jake?']
# ['Guy', 'Today and last night']
# ['Mema Nackasha', 'He says he was feeling anxious from the big crowds today']
# ['Mema Nackasha', 'I even asked if it was anything to do with me or you']
# ['Mema Nackasha', 'And he said absolutely not']
# ['Mema Nackasha', 'He did go back to normal when we sat down in cafe rouge']
# ['Mema Nackasha', '\u200eMissed voice call']
# ['Mema Nackasha', 'Flat hunting has begun btw']
# ['Mema Nackasha', "I'm looking around Camden"]
# ['Mema Nackasha', "It'll obvs take a little while"]
# ['Mema Nackasha', "But you'll be living with me soon bébé"]
# ['Mema Nackasha', "Also I told my mum and she's so upset and she said please give the money to guy and tell him he doesn't need to pay us back if he can't or he can take as long as he wants to pay back"]
# ['Mema Nackasha', 'Soooooooo']
# ['Mema Nackasha', "But Camden is cool isn't it !!!"]
# ['Mema Nackasha', "And then we'll northern line to work in like 15 mins"]
# ['Guy', 'Thanks bb']
# ['Guy', 'Honestly, there is no one to blame but myself']
# ['Guy', 'Even though I imply otherwise']
# ['Mema Nackasha', 'No but u r mine']
# ['Mema Nackasha', "What's mine is yours xx"]
# ['Guy', 'Hahahah']
# ['Mema Nackasha', 'U and Jakey']
# ['Mema Nackasha', '😃']
# ['Guy', 'That would be amazing']
# ['Guy', "But please don't let anyone but yourself be a factor in the decision"]
# ['Mema Nackasha', 'Which bit']
# ['Mema Nackasha', 'The flat or giving you 4 grand']
# ['Guy', 'The flat']
# ['Guy', "And don't worry about the money, I'm gonna borrow it from my mum"]
# ['Mema Nackasha', "I don't know which other opinions would change anything"]
# ['Mema Nackasha', 'I wanna live with my best pal :)']
# ['Mema Nackasha', 'And as jake already has a flat']
# ['Mema Nackasha', 'I HAVE to choose you']
# ['Mema Nackasha', 'Duh']
# ['Guy', 'Dope 😊']
# ['Mema Nackasha', 'Mwah']
# ['Guy', 'Cutie']
# ['Guy', "That's great haha"]
# ['Guy', 'I should have done that']
# ['Mema Nackasha', 'Yeah should have got the abs out yep']
# ['Guy', 'Always']
# ['Guy', 'Nice Prof pic btw!']
# ['Mema Nackasha', 'Hahaha']
# ['Mema Nackasha', 'Thanks boo']
# ['Mema Nackasha', 'I love it too']
# ['Mema Nackasha', 'My babies ❤❤❤']
# ['Mema Nackasha', 'Playing a game of "let\'s see how many animals we can see without going into the barbaric zoo"']
# ['Guy', 'Hahaha 😂']
# ['Mema Nackasha', '😃']
# ['Mema Nackasha', 'Btw which evening are you free this week for me and jake to come over and cook']
# ['Guy', 'Hmmm inviting yourself round eh?']
# ['Guy', "It's not like we're married"]
# ['Mema Nackasha', 'Jake said you said we could']
# ['Mema Nackasha', '... YET']
# ['Mema Nackasha', 'I dream of the day mr Robertson']
# ['Guy', 'No I said Jake could come']
# ['Guy', 'Jk how about Wednesday?']
# ['Mema Nackasha', 'O']
# ['Mema Nackasha', 'Phew']
# ['Mema Nackasha', 'PERFECT 😃']
# ['Mema Nackasha', "Once I've had a lil bit of you I crave you more"]
# ['Mema Nackasha', "So now you're lumbered with me"]
# ['Guy', 'Hahah']
# ['Guy', "Why hasn't Jake been invited"]
# ['Mema Nackasha', "I'm just kidding of course he'll come"]
# ['Guy', "I didn't mean to say that"]
# ['Guy', "I meant why hasn't Jake been responding?"]
# ['Mema Nackasha', "Sometimes he doesn't sleep well and then he crashes at like 7pm when he gets home"]
# ['Guy', 'That sucks']
# ['Guy', "I couldn't do it"]
# ['Mema Nackasha', "Me either it's so horrendous poor thing lm"]
# ['Guy', 'Wait so is Jake coming or not?']
# ['Mema Nackasha', "Course he'll come"]
# ['Mema Nackasha', 'I might stay over after']
# ['Mema Nackasha', 'Would that be ok']
# ['Guy', 'Yeah of course']
# ['Mema Nackasha', "It's just an effort to get back to Camden"]
# ['Guy', 'And go straight to work from mine?']
# ['Mema Nackasha', 'Thanks honeybunch']
# ['Guy', 'Noice!']
# ['Mema Nackasha', 'Yep yep :)']
# ['Mema Nackasha', 'So I can stay up and hang with you in the evening']
# ['Mema Nackasha', "Or else I'd have to leave at like 10 to get home for 11 hahaa"]
# ['Guy', 'Defo stay']
# ['Mema Nackasha', 'Promotion has been confirmed']
# ['Mema Nackasha', "I'm scared"]
# ['Mema Nackasha', "I'm taking over the whole of the inside sales which means I'll be account manager for all 400 of our UK eTap customers"]
# ['Mema Nackasha', "Also I'm continuing my current role as well"]
# ['Mema Nackasha', "Which means that I'm doing 2 jobs basically"]
# ['Guy', 'Hahaha']
# ['Mema Nackasha', 'And my targets are gonna increase but that means I can make so much more commission too']
# ['Mema Nackasha', 'training starts tomorrow']
# ['Guy', 'Dope!']
# ['Mema Nackasha', 'Scary']
# ['Guy', "It's great that they are properly utilising your talent"]
# ['Mema Nackasha', 'Yes they are lovely']
# ['Guy', 'Btw just a thought']
# ['Mema Nackasha', 'Is it that you love me']
# ['Guy', 'But perhaps it might be a little bit bad to talk about my incredible amazing body in front of people aka Jake?']
# ['Mema Nackasha', 'What why']
# ['Guy', "Obv we have nothing to hide but it's the kind of thing you don't want to hear from the love of your life?"]
# ['Mema Nackasha', "I'm obsessed with both of you"]
# ['Mema Nackasha', 'Oh']
# ['Mema Nackasha', 'But selfishly']
# ['Mema Nackasha', "This is the exact kind of thing I don't want to have to think about"]
# ['Mema Nackasha', "We're not together"]
# ['Mema Nackasha', "We're all friends"]
# ['Mema Nackasha', "I don't want to start worrying that I can't cuddle you"]
# ['Mema Nackasha', 'Or him']
# ['Mema Nackasha', 'Or anyone']
# ['Mema Nackasha', "or say I'm seeing marie for example"]
# ['Mema Nackasha', 'Ya know']
# ['Guy', "Yeah if course but it's just basic sensitivity, you're not expected to go out your way to do anything"]
# ['Mema Nackasha', "Ok I'll keep the abs to myself"]
# ['Guy', 'I totally get that you just want to relax with your friends and enjoy yourself']
# ['Guy', "That's really fair"]
# ['Mema Nackasha', 'Yep']
# ['Mema Nackasha', 'And I don\'t want to have to think "especially be careful with guy"']
# ['Mema Nackasha', 'Because of 7 years ago']
# ['Mema Nackasha', "Ya know that's tiring"]
# ['Mema Nackasha', 'I thought Jake was sad on the weekend because it was me and you']
# ['Mema Nackasha', "But he swears down that wasn't the case"]
# ['Guy', "I'd hope that you wouldn't have to be especially different around me either"]
# ['Guy', "Btw this is the reason why I keep pushing you off me and stuff, if you didn't realise"]
# ['Mema Nackasha', 'Nope']
# ['Mema Nackasha', 'I climb all over jake too']
# ['Mema Nackasha', "It's not like it's only you"]
# ['Mema Nackasha', 'I understand the issue']
# ['Guy', "I don't want to upset you or put pressure on you"]
# ['Mema Nackasha', "But I like to think there's no issue"]
# ['Mema Nackasha', 'Just like move on']
# ['Mema Nackasha', "I don't want my best friend to be in love with me"]
# ['Guy', 'Yeah']
# ['Mema Nackasha', "It's horrible really to hear that he thinks he's never been in love properly because it's only ever been with me"]
# ['Mema Nackasha', "That's obviously flattering"]
# ['Mema Nackasha', "But then afterwards it's daunting"]
# ['Mema Nackasha', "So I feel like he has to understand that it's not gonna happen"]
# ['Mema Nackasha', 'Not now anyway']
# ['Guy', 'Yeah']
# ['Guy', 'I just']
# ['Guy', 'I guess the empathy hurts me too']
# ['Mema Nackasha', "I don't want to directly or indirectly hurt anyone 😩 I just want to fancy my best friends and get on with my life"]
# ['Guy', 'Hahahah']
# ['Guy', 'And get married']
# ['Guy', 'To us']
# ['Guy', '😘']
# ['Mema Nackasha', 'Yes']
# ['Mema Nackasha', '❤👨\u200d👨\u200d👧❤']
# ['Mema Nackasha', 'baby boy with your little blueberry muffins !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!']
# ['Mema Nackasha', 'so cuuuuuuuuuuuuuuuuuuuuuuute']
# ['Mema Nackasha', '💙💙💙💙💙💙💙💙']
# ['Mema Nackasha', 'since getting to work ALL we have done is try and work out the name of that song !!!!!!!!!!!']
# ['Mema Nackasha', "it's driving us all mental"]
# ['Mema Nackasha', 'the boys are googling']
# ['Mema Nackasha', 'we thought of the lyrics ohhhhh yeahhhh']
# ['Mema Nackasha', "that's it so far hahaa"]
# ['Mema Nackasha', 'btw thanks so much for having me i had such a lovely evening :) :)']
# ['Guy', "Hahaha we'll never get it"]
# ...
# ['Guy', 'And heating doesn’t seem to be coming on again']
# ['Mema Nackasha', 'oooh']
# ['Mema Nackasha', "i haven't seen that error"]
# ['Mema Nackasha', 'uh ohhhh']
# ['Mema Nackasha', 'were you just turning the thermostat on and off? not touching the boiler?']
# ['Guy', 'I turned it off at the boiler earlier today as well cos it was making a lot of noise and we didn’t need it']
# ['Mema Nackasha', 'oh damn']
# ['Guy', 'Just turned it back obvs']
# ['Guy', 'It hasn’t turned back on']
# ['Mema Nackasha', 'and the thermostat is on?']
# ['Guy', 'Yeah']
# ['Guy', 'It should be making a lot of noise now but it’s not']
# ['Mema Nackasha', 'yup']
# ['Mema Nackasha', "i've messaged the boiler"]
# ['Mema Nackasha', '*plumber']
# ['Guy', 'Cool']
# ['Mema Nackasha', 'press the down button until you can see the pressure']
# ['Mema Nackasha', 'it should be 0.something or 1.something']
# ['Guy', 'What’s the code for pressure?']
# ['Mema Nackasha', "i'm not sure"]
# ['Mema Nackasha', "the manual's in the top drawer"]
# ['Guy', 'That’s not good']
# ['Mema Nackasha', "okay that's rock bottom lol"]
# ['Mema Nackasha', 'so on the pipe that was leaking']
# ['Mema Nackasha', "it's been replaced"]
# ['Guy', 'Ok']
# ['Mema Nackasha', "there's no longer a black screwey thing on the left"]
# ['Mema Nackasha', 'the right should still be a twisty black thing']
# ['Mema Nackasha', 'send me a pic so i can draw on it']
# ['Guy', 'Shall I turn them to increase the pressure?']
# ['Mema Nackasha', 'yeah but the left one requires a screw driver']
# ['Mema Nackasha', 'a basic one']
# ['Mema Nackasha', 'send me a picture so i can show you were to screw']
# ['Guy', 'Yeah got it']
# ['Guy', 'The boiler has come on now']
# ['Mema Nackasha', 'woo']
# ['Mema Nackasha', 'excellent']
# ['Mema Nackasha', "pressure's up?"]
# ['Mema Nackasha', 'the radiators were all bled so they should be okay']
# ['Guy', 'Pressure is at 0.9 and won’t go any higher']
# ['Guy', 'But the heating is on']
# ['Mema Nackasha', 'okay']
# ['Mema Nackasha', "the pump's been changed"]
# ['Guy', 'I’m just gonna leave it at the boiler so this doesn’t happen again but I would have assumed this would increase your bill a lot']
# ['Guy', '🤷\u200d♂️']
# ['Mema Nackasha', "i'll let u know if that's the case loool"]
# ['Mema Nackasha', "but at the mo, the priority is that you're warm"]
# ['Guy', 'Thanks ❤️']
# ['Mema Nackasha', '❤️ ❤️']
# ['Guy', 'Ok it’s stopped for now']
# ['Guy', 'But there doesn’t seem to be a battery or anything so I’m not sure what the blipping means']
# ['Mema Nackasha', 'Hmmmm there must be a battery righttttttt']
# ['Mema Nackasha', 'Is there a model number or anything']
# ['Guy', 'You’d think so but it’s connected with a wire']
# ['Mema Nackasha', 'Hahahaha']
# ['Mema Nackasha', 'How dramatic']
# ['Mema Nackasha', 'It’s like Phoebe again']
# ['Mema Nackasha', 'I’ll google']
# ['Mema Nackasha', 'And ask the group actually as I’m sure everyone has the same']
# ['Guy', 'It has stopped for now for some reason']
# ['Guy', 'I didn’t really do anything']
# ['Mema Nackasha', 'Lol okie let me know if it starts up again']
# ['Guy', 'Yeah it’s just started']
# ['Guy', 'I’m gonna rip it out if it doesn’t stop']
# ['Guy', 'Literally cannot live with this']
# ['Mema Nackasha', 'Can you send me a picture of the inside of it']
# ['Guy', 'Ok I’ve taken it off the ceiling and pulled the battery out']
# ['Mema Nackasha', 'I couldn’t catch a model number']
# ['Mema Nackasha', 'Ok']
# ['Mema Nackasha', 'Is it a normie battery?']
# ['Mema Nackasha', 'Sweet']
# ['Guy', 'Sorry for being short I was having technical difficulties with my camera and then the beeping started 😂']
# ['Mema Nackasha', 'No worries xx']
# ['Mema Nackasha', ':)']
# ['Guy', 'You’re the best landlady ever xx']
# ['Mema Nackasha', 'I’m trying 🥺💛']
# ['Guy', 'Hey you didn’t see a little USB stick type thing near my work laptop did you?']
# ['Mema Nackasha', 'Not that I remember :/']
# ['Guy', 'Yeah don’t worry I think it was me']
# ['Guy', 'Just lost it completely']
# ['Mema Nackasha', 'lolol']
# ['Guy', 'Can’t work without it 😕']
# ['Mema Nackasha', 'have you got it back?']
# ['Guy', 'No but I called IT and thankfully I can actually work without it with a temporary measure']
# ['Mema Nackasha', 'Okie']
# ['Guy', 'Btw where did you get to with refurbingthe living room in terms of the cushions and rug and stuff']
# ['Guy', 'I’m looking at getting a throw blanket and I don’t want it to clash']
# ['Mema Nackasha', 'couldn’t find an ethical company that had cool stuff so get what you like and I’ll match to you']
# ['Guy', 'Okie dokie']
# ['Mema Nackasha', 'yes please']
# ['Mema Nackasha', "perfect, they've both emailed me the same stuff,can you just chuck the letters in my room? :) thank you!! sorry for being inconveniencing !"]
# ['Guy', 'Sure and no worries x']
# ['Guy', 'How’s your book editing going?']
# ['Mema Nackasha', "really good :) i've put some super tight deadlines in to get a first draft done by the end of the year"]
# ['Mema Nackasha', 'exciting']
# ['Guy', 'Nice 😄']
# ['Guy', 'Any prospect of publication?']
# ['Mema Nackasha', 'We’ll go to publishers in jan! So hopefully!']
# ['Guy', 'À British publisher?']
# ['Mema Nackasha', 'Possibly']
# ['Mema Nackasha', 'How’s quarantine ? Have the NHS called or showed up to check on you?']
# ['Guy', 'Very excite into']
# ['Guy', 'Exciting!']
# ['Mema Nackasha', ':)']
# ['Mema Nackasha', 'It’s a fun project for sure']
# ['Guy', 'Yeah they called 3 days in a row actually']
# ['Mema Nackasha', 'Wow!']
# ['Guy', 'Only answered on the 3rd day']
# ['Mema Nackasha', 'Did you get in trouble?']
# ['Guy', 'Nope was a pretty chilled call']
# ['Mema Nackasha', 'Oh ']
# ['Guy', 'Basically wanted to check that I knew I had to self isolate and that I was doing so']
# ['Mema Nackasha', 'Hahahaha']
# ['Guy', 'Quarantine is good except we have run out of vegetables haha']
# ['Guy', 'Because we have nothing to do we’re cooking really elaborate meals and going through everything so quickly']
# ['Mema Nackasha', 'Oh nooooo!! Are there any delivery slots?']
# ['Mema Nackasha', 'Haha fair']
# ['Guy', 'Haven’t checked but we’re going to']
# ['Mema Nackasha', 'Sweet']
# ['Mema Nackasha', 'Us']
# ['Mema Nackasha', 'Amazing pic']
# ['Guy', 'Thanks 😄']
# ['Guy', 'Hahahahaaa']
# ['Guy', 'That was with us away for a week as well']
# ['Mema Nackasha', 'Yes! But I was on video calls for 4 days straight in your absence haha']
# ['Mema Nackasha', 'Resets in 2 days']
# ['Mema Nackasha', 'But good to know roughly :)']
# ['Mema Nackasha', 'Can always upgrade again if needed']
# ['Guy', 'Hahahahaha']
# ['Mema Nackasha', 'Hope you’re doing okay in quarantine! Xxx']
# ['Mema Nackasha', 'Btw shams broke up with me']
# ['Guy', 'What do you mean?']
# ['Guy', 'Like doesn’t want to be friends anymore?']
# ['Mema Nackasha', 'Yeahhhh']
# ['Guy', 'What why how?']
# ['Mema Nackasha', 'You haven’t upset me, I feel friendships can change and morph through time/situations  and that’s absolutely ok and we should learn to accept that. This doesn’t mean I have any less love for you or the times we’ve shared together. I’ll always be grateful for your support and laughs when I’ve needed it and I believe I’ve always told you how appreciative I’ve been of your help. However in the last few months I felt a shift towards unhealthy power dynamics between us. I felt I was always chasing to repay you in some way or another, in a way I didn’t have the capacity to.']
# ['Mema Nackasha', "thank you for being so honest with me and you're right about friendships changing! i think if you felt it was worth fighting for us to stay close then you would have spoken to me about this stuff - particularly the speaking behind your back - before, so i completely respect your decision. i don't want to be defensive about the way i've made you feel, but i'm especially sorry that you've felt patronised or in debt to me - i maintain that you've never owed me anything - you spent hours looking after me in your garden all summer!  "]
# ['Mema Nackasha', 'Thanks for being understanding of how I’ve felt towards our friendship. I’m at a space where I feel it doesn’t make sense to force or fight for things in my life that don’t sit well with me or feel uneasy/inbalanced. I’m not saying that means no interaction just maybe means redefining our friendship.  ']
# ['Mema Nackasha', 'In case you’re bored and literally have nothing to do looolll']
# ['Guy', 'That’s a shame']
# ['Guy', 'I’m sorry to hear that']
# ['Guy', 'Seems like the issues didn’t get resolved a while ago when they should have been']
# ['Mema Nackasha', 'Yeah I agree but oh wellllll ']
# ['Guy', 'Yeah it was fair enough, sounded largely out of your control']
# ['Guy', 'ESP the stuff about her feeling uncomfortable like she owes you something']
# ['Mema Nackasha', 'Is quarantine over? Are you okay? :) xx']
# ['Guy', 'Yep!']
# ['Guy', 'All good']
# ['Guy', 'Went outside walking and it was weird']
# ['Mema Nackasha', 'Hhahahaa']
# ['Mema Nackasha', 'I imagine you like touching the floor confused about what concrete is']
# ['Guy', 'Yeah']
# ['Guy', 'Seeing other people was surprisingly weird']
# ['Guy', 'Felt like I was seeing like an exotic animal']
# ['Mema Nackasha', 'Hahahahahaa']
# ['Mema Nackasha', 'Just remembered this!! Did the desk arrive??']
# ['Guy', 'No haha']
# ['Mema Nackasha', 'Can you check the email?']
# ['Mema Nackasha', 'Okay we can chase next week if we’ve still not heard anything']
# ['Mema Nackasha', '12 weeks is this weekend I believe']
# ['Mema Nackasha', 'Can you forward me the email mnackasha@hotmail.com and I’ll see if I can track it down :?']
# ['Mema Nackasha', 'Wow']
# ['Mema Nackasha', 'Okay!']
# ['Guy', '14 Dec']
# ['Mema Nackasha', 'In time for Christmas lol']
# ['Guy', 'Haha']
# ['Mema Nackasha', 'Have you got that time off?']
# ['Guy', 'Ill be wfh around then']
# ['Mema Nackasha', 'Okie']
# ['Guy', 'I rearranged my room way earlier than I needed to 😂']
# ['Mema Nackasha', 'Hahahahaa']
# ['Mema Nackasha', 'But it still looks better this way right?']
# ['Guy', 'Yeah about the same']
# ['Mema Nackasha', 'Is Alison gonna be over tomorrow? :)']
# ['Guy', 'Yeah and you?']
# ['Mema Nackasha', 'yeah i wanna come but also not if you guys have plans !']
# ['Guy', 'No for sure come!']
# ['Mema Nackasha', 'I’ll be there!']
# ['Mema Nackasha', 'Around 6.30ish I hope :):)']
# ['Mema Nackasha', 'Did you have dinner planned?']
# ['Guy', 'Noice']
# ['Guy', 'Not yet but I will']
# ['Mema Nackasha', 'Let me know! I can bring bits and we can cook or we can get burgers']
# ['Mema Nackasha', 'I’m easy y’a know']
# ['Guy', 'That’s what she said']
# ['Mema Nackasha', 'Name of your sex tape']
# ['Guy', 'We’re actually thinking not burgers just cos we’ve had a lot of fried food lately']
# ['Mema Nackasha', 'Okie!']
# ['Mema Nackasha', 'I’m happy with anything']
# ['Mema Nackasha', 'Nope!']
# ['Mema Nackasha', 'Is it vegan?']
# ['Guy', 'Yep']
# ['Guy', 'It was Matt 😊']
# ['Guy', 'Btw you know Ready Player Two is out?']
# ['Guy', 'Book']
# ['Mema Nackasha', 'I heard !!']
# ['Mema Nackasha', 'I thought the film was also coming out']
# ['Mema Nackasha', 'Shall we read it ?']
# ['Guy', 'Yeah I might do at some point!']
# ['Guy', 'Alison and I are reading the Handmaid’s Tale']
# ['Guy', 'Btw were thinking of doing lasagne tonight']
# ['Mema Nackasha', 'Awesome']
# ['Mema Nackasha', 'Love this book']
# ['Mema Nackasha', 'Lovely']
# ['Guy', 'Yeah I’m really liking it, defo keen to read the next one after x']
# ['Mema Nackasha', 'It’s amazing! And on my shelf :D']
# ['Guy', 'Yep I see hah']
# ['Guy', 'Thanks!']
# ['Mema Nackasha', 'What ingredients can I bring']
# ['Mema Nackasha', 'Walking past Tesco in a sec']
# ['Guy', 'You coming here now?']
# ['Guy', 'I need to go shopping at the big Sains so dw about it but thanks!']
# ['Mema Nackasha', 'I’m planning to leave at 5 and drive']
# ['Guy', 'Oh ok']
# ['Mema Nackasha', 'So I’ll be back for 6ish hopefully']
# ['Mema Nackasha', 'But very soon!!']
# ['Guy', 'Coolio']
# ['Mema Nackasha', 'Has Alison been working in the flat during the days btw']
# ['Guy', 'Not this week but when we were self isolating yeah']
# ['Guy', 'How come?']
# ['Mema Nackasha', 'Just was wondering about internet that’s all!']
# ['Guy', 'Ahh ok']
# ['Guy', 'Based on the type of work she does I expect my data requirements are much higher than hers']
# ['Guy', 'And we always watched tv etc together']
# ['Guy', 'Happy to pay extra for the bills though! Just let me know how much if it’s higher']
# ['Mema Nackasha', 'That’s okay !!!']
# ['Mema Nackasha', 'No worries at all b, the most important thing is that the internet is good enough 🥺❤️']
# ['Mema Nackasha', 'I think I left my mug on the windowsill I’m sorry!!']
# ['Guy', 'No problem xx']
# ['Guy', 'Miss you already!']
# ['Guy', 'So nice to see you']
# ['Mema Nackasha', 'Miss you too!! Was so good to be home 🥰💛']
# ['Guy', '❤️❤️❤️❤️❤️']
# ['Guy', 'Love you x']
# ['Mema Nackasha', '❤️']
# ['Guy', 'Got a remote control for the tv']
# ['Guy', 'And also got the sound bar and it’s amaaaziny']
# ['Mema Nackasha', 'Awesome!']
# ['Guy', 'Weird question']
# ['Guy', 'You didn’t by any chance take a duvet cover home with you when you last came did you?']
# ['Mema Nackasha', 'Haha no']
# ['Mema Nackasha', 'But the one in my room might be the one you’re asking about as there’s an extra one in the spare room and I just grabbed one of them']
# ['Mema Nackasha', 'So take it of course']
# ['Mema Nackasha', 'Option b is check under the spare bed in the drawers or in the black and white laundry basket']
# ['Guy', 'Ahh yeah it’s here, thank you!!']
# ['Guy', 'Up to much this weekend? C']
# ['Mema Nackasha', 'And I have a cafi meeting']
# ['Mema Nackasha', 'And working on the book']
# ['Mema Nackasha', 'That’s all really']
# ['Guy', 'Nice! That’s great']
# ['Mema Nackasha', 'You? :)']
# ['Guy', 'How far is the book?']
# ['Guy', 'Just visiting my mum now and going to Blues Kirchen later with Alison x']
# ['Mema Nackasha', 'That’s lovely :) have fun!']
# ['Mema Nackasha', 'We’ve got a first draft as of today :) so lots of editing now and then we’ll start approaching publishers']
# ['Guy', 'I’m sure you’ll get a Pulitzer']
# ['Mema Nackasha', 'Thank you so much 🥺❤️']
# ['Mema Nackasha', 'Just spotted we’re running low on internet so I’m calling now to upgrade (in case it drops out momentarily)']
# ['Guy', 'Yeah video game updates can be quite a lot and I’ve had a few of those lately']
# ['Guy', 'Likely 10s of gigabytes']
# ['Guy', 'Like*']
# ['Guy', 'How much does it cost to upgrade?']
# ['Guy', 'Also thanks!']
# ['Mema Nackasha', 'So we’re currently paying £31 for 300GB a month but we’ve basically run out and have 9 days left of the month']
# ['Mema Nackasha', 'The upgrade is unlimited for £50 a month but I’m asking for a discount']
# ['Mema Nackasha', 'Because that’s a big jump up']
# ['Mema Nackasha', 'But tbh we were paying £20 for BT internet and that didn’t even work']
# ['Guy', 'Yah']
# ['Guy', 'I’m happy to pay extra for that']
# ['Guy', 'When I get a PS5 it’s gonna use a lot of data haha']
# ['Mema Nackasha', '500 GB is £40.50']
# ['Guy', 'I’d go for unlimited just for peace of mind']
# ['Mema Nackasha', 'I’m saying unlimited !']
# ['Guy', 'Cool x']
# ['Mema Nackasha', 'Hahaha']
# ['Mema Nackasha', 'Yes :)']
# ['Mema Nackasha', 'Done x']
# ['Mema Nackasha', 'God I love EE']
# ['Mema Nackasha', 'Is that a rug']
# ['Guy', 'Hahaha no just a meme']
# ['Mema Nackasha', 'I’m squinting']
# ['Guy', 'Angle your phone']
# ['Mema Nackasha', 'hahahhaha awww ❤️ i was turning it and twisting ❤️ ❤️']
# ['Guy', '❤️']
# ['Guy', 'Btw increased my rent by £20 for the extra internet costs']
# ['Guy', 'Remember all the giant iguanas!']
# ['Guy', 'Or whatever they were']
# ['Guy', 'Oh yeah and pls could you remove the child lock on the internet? 😂']
# ['Mema Nackasha', 'Loool that took so long to work out how to do but done x x x']
# ['Mema Nackasha', 'Might take 30 mins to refresh']
# ['Guy', 'Thank you!']
# ['Guy', 'A mans got needs 😅']
# ['Guy', 'I’m actually at the Shard rn though']
# ['Mema Nackasha', 'Hahahaa a gal does too x']
# ['Mema Nackasha', 'That’s cute']
# ['Mema Nackasha', 'The cocktails are great I remember']
# ['Guy', 'Yeah splashing out']
# ['Guy', 'Feels normal']
# ['Guy', 'As in, going out and having fun']
# ['Guy', 'The desk is amazing!!']
# ['Guy', 'Thank you!!! ❤️']
# ['Guy', 'Btw you got a Christmas card, want me to open it and show you?']
# ['Mema Nackasha', 'YAYY!']
# ['Mema Nackasha', 'And yes please :)']

# %%
chat
# Out:
# ['Mema Nackasha: \u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.',
#  'Mema Nackasha: What are you doing',
#  'Mema Nackasha: Were you drunk',
#  "Guy: I'm at work",
#  "Guy: Just cba'd to take a quality photo",
#  'Mema Nackasha: No I meant last night',
#  'Mema Nackasha: Pic',
#  "Mema Nackasha: You looked cute in today's pis",
#  'Guy: Thnx',
#  'Guy: Wanna come round on Saturday evening?',
#  "Guy: We're gonna go out to pubs and bars in my area",
#  'Mema Nackasha: Yeah maybs baby ! Sounds good!',
#  'Mema Nackasha: Who else did you invite ?',
#  'Guy: Jake',
#  'Mema Nackasha: Oh I dunno if I get on well with that one',
#  "Mema Nackasha: I'll think about it xx",
#  'Guy: And Kian',
#  'Guy: And probs Annie',
#  "Mema Nackasha: Don't like any of those people",
#  'Mema Nackasha: Lol jk',
#  'Mema Nackasha: Sounds awesome',
#  'Guy: When are you gonna be around?',
#  'Mema Nackasha: 5 mins',
#  'Guy: Srsly?',
#  'Mema Nackasha: Find friends me',
#  "Mema Nackasha: If you're having sex I can detour",
#  "Guy: No I'm not lol",
#  'Guy: I see you!',
#  'Mema Nackasha: Am i looking cute',
#  'Guy: How was interview?',
#  'Guy: And what was it for?',
#  "Mema Nackasha: Omg it was the most horrible experience I'm drained",
#  'Mema Nackasha: It was a group interview',
#  'Guy: Oh lame',
#  'Mema Nackasha: I got it tho',
#  'Guy: Sorry with people',
#  'Mema Nackasha: It was just a horrible process',
#  "Guy: What's the job?",
#  "Mema Nackasha: It's a sales recruiter so they'll call me tomorrow with jobs",
#  'Mema Nackasha: Today was just the interview process',
#  'Mema Nackasha: Wolfestone',
#  "Mema Nackasha: Appaz it's the best one",
#  'Guy: Oh right',
#  'Mema Nackasha: I was in a room with 32 other people who all had a first and all spoke languages and were all bubbly',
#  "Mema Nackasha: I was certain I wouldn't get through",
#  "Mema Nackasha: I'm dead it was horrible",
#  'Guy: Hahaha',
#  'Guy: Awesome! Not even surprised 😊',
#  'Mema Nackasha: I am',
#  "Mema Nackasha: I'm drained",
#  "Guy: How come you've done so much for sales recruiting?",
#  "Mema Nackasha: Because everyone I've spoken to says I have the personality for it",
#  'Mema Nackasha: I did get asked in the interview if I was too nice for sales tho lols',
#  'Guy: Oh yeah',
#  'Guy: Interesting',
#  'Mema Nackasha: And also because I spoke to a couple of random people',
#  'Mema Nackasha: Randomly',
#  'Mema Nackasha: Who studied languages and then went into political activism',
#  'Mema Nackasha: And they said they wished they got a proper job first',
#  'Mema Nackasha: Then gone into it after r',
#  'Mema Nackasha: And I was like k',
#  'Guy: How come?',
#  'Mema Nackasha: 1 said it was because of the money',
#  'Mema Nackasha: And the other said it would have been nice to experience the working world properly',
#  'Mema Nackasha: Which is what I wanna do I guess',
#  'Mema Nackasha: For a bit anyway',
#  'Guy: Yah',
#  "Mema Nackasha: I'm already feeling claustrophobic about not having time off to travel whenever I want now",
#  "Mema Nackasha: I don't like that",
#  "Guy: You're gonna kill it in sales",
#  'Guy: Hahahaah',
#  "Guy: That's hilar",
#  'Mema Nackasha: But all the girls today were literal models',
#  'Mema Nackasha: Everyone was posh',
#  'Mema Nackasha: I was like hey yo',
#  'Guy: Like u',
#  'Mema Nackasha: Lol',
#  'Mema Nackasha: I felt so uncomfortable',
#  "Mema Nackasha: And I wasn't even wearing heels cos cba",
#  "Mema Nackasha: So I was so certain they'd be like nah",
#  'Mema Nackasha: It was so draining',
#  'Mema Nackasha: Bleugh',
#  'Guy: I would do so badly at sales',
#  'Guy: In other languages esp',
#  "Mema Nackasha: But you're an astronaut doodies",
#  'Mema Nackasha: Also one of the group tasks',
#  'Mema Nackasha: Was a list of items',
#  'Mema Nackasha: And we had to order them',
#  'Mema Nackasha: In importance',
#  'Mema Nackasha: Of if your rocket crashed on the moon',
#  "Mema Nackasha: And j was like where's my astronaut 😩",
#  'Guy: Hahahaah',
#  'Guy: I had the same thing!',
#  'Guy: Except it was like historical inventions',
#  'Mema Nackasha: Well of course you did',
#  'Mema Nackasha: Oh',
#  'Guy: Like the wheel and the Internet',
#  "Mema Nackasha: The internet is an important one isn't it",
#  'Guy: Yep',
#  'Mema Nackasha: 😩',
#  "Mema Nackasha: I've decided I'm going to retire xx",
#  'Guy: Hahahaah was it really hard',
#  'Mema Nackasha: Nah it was just some training',
#  'Mema Nackasha: But Lololol',
#  'Mema Nackasha: Miss u',
#  "Mema Nackasha: I've forgotten what you look like",
#  'Guy: Ready for interview?',
#  'Guy: Lol',
#  'Mema Nackasha: Kinda',
#  'Mema Nackasha: Me and Jake are having our first argument btw',
#  'Guy: Bout what?',
#  'Guy: Drama lama',
#  'Guy: How do you feel?',
#  'Guy: Look wha Annie made me!',
#  'Guy: While I was at work',
#  'Mema Nackasha: Omg jeal !!!',
#  'Guy: You and Jake have both had the same issue with one another',
#  "Mema Nackasha: That's kind of her",
#  'Mema Nackasha: And I cba BLUGH',
#  'Mema Nackasha: It was a real argument :(',
#  "Mema Nackasha: We've ever argued",
#  "Mema Nackasha: And we didn't even fix it",
#  "Mema Nackasha: And I said I'm going to bed good night",
#  "Mema Nackasha: And we didn't fix the argument :(",
#  "Guy: I'm sure you will",
#  "Guy: Don't worry",
#  'Guy: Your friendship is stronger than this',
#  "Mema Nackasha: Yes but now I'm upset",
#  "Mema Nackasha: He's been ignoring me since Friday",
#  'Mema Nackasha: Not as a joke',
#  'Mema Nackasha: Like he actually was Angry at me',
#  'Guy: Sorry babe 😩',
#  'Guy: Want me to do anything about it?',
#  'Mema Nackasha: In even worse news, bake off is moving to channel 4 which means adverts',
#  "Mema Nackasha: And no its ok thanks he'll probably be mad I told you",
#  'Guy: Fuck adverts',
#  'Guy: We can probably watch it on 4od right?',
#  'Mema Nackasha: But that has adverts !!',
#  'Guy: Oh fuck this',
#  'Mema Nackasha: Shall I drive to his and give him a hug',
#  "Mema Nackasha: I'm feeling so sad",
#  'Guy: Up to you',
#  'Mema Nackasha: I did it !!!',
#  'Mema Nackasha: MHH',
#  'Mema Nackasha: All is good',
#  'Guy: Lol of course you did',
#  'Mema Nackasha: Did you snap me today',
#  "Mema Nackasha: I'm not sure you did",
#  'Mema Nackasha: Also me and bunny are so cute',
#  'Guy: Here you go',
#  'Mema Nackasha: Mmh',
#  'Guy: Are you doing the interview tomorrow then',
#  'Mema Nackasha: Yes',
#  'Guy: Good luck!',
#  'Guy: Just be yourself',
#  'Mema Nackasha: Merci bébé ',
#  'Guy: Annie says this',
#  'Guy: Tell Mema to be my best friend and keep me in baba ghanoush',
#  'Guy: I think she means ".. make me baba ghanoush" lol',
#  'Mema Nackasha: Hahaha cute',
#  "Mema Nackasha: Yeah let's do one night at the flat and I'll make baba ghanoush",
#  'Mema Nackasha: Fo sho',
#  'Guy: Awesome!',
#  'Guy: Would weekday or weekend be better for you?',
#  "Mema Nackasha: I like weekdays because I don't like being in the flat alone haha",
#  'Guy: Passed 1/3 exams 😖',
#  'Mema Nackasha: 😠',
#  "Mema Nackasha: If my cleverest astronaut can't pass them then they're dumb exams wtf",
#  'Guy: Yeah exactly haha',
#  'Mema Nackasha: R u mad or sad',
#  'Guy: 😘',
#  'Mema Nackasha: Congrats on the one you passed btw 😘😘😘😘😘',
#  'Guy: Thanks',
#  "Mema Nackasha: I'm going to Paris tonight woo",
#  'Guy: Lol',
#  'Guy: Send us some pics',
#  'Mema Nackasha: Would you come to Weybridge for new year',
#  "Mema Nackasha: Because Jake's not doing it at his",
#  "Mema Nackasha: So he's thinking of getting everyone to the crown",
#  'Mema Nackasha: Not my favourite idea but I just want to be with you guys basically',
#  'Mema Nackasha: Ok more likely going to jakes flat phewwwwww',
#  'Guy: Yay jakes flat is best',
#  'Mema Nackasha: Perfect',
#  'Mema Nackasha: Is Annie about?',
#  "Guy: She's party hopping",
#  'Mema Nackasha: Will she be dropping in with us?',
#  "Guy: So she'll come to us for a bit",
#  'Mema Nackasha: Ok cool beans',
#  "Mema Nackasha: Can't wait",
#  "Mema Nackasha: For the last few hours jake said he wasn't having a party and that we were going to the crown and I was not happy about that",
#  "Mema Nackasha: I don't like the crown",
#  'Mema Nackasha: So yayyyy perfect',
#  'Guy: Does he actually want to though?',
#  "Guy: We shouldn't make him do it",
#  'Guy: Even though he said he would weeks ago',
#  'Mema Nackasha: No he does',
#  'Mema Nackasha: Nobody is making him dw',
#  'Guy: Kewl',
#  'Mema Nackasha: Shall I come around 6ish with',
#  'Mema Nackasha: Or earlier or later',
#  'Mema Nackasha: Jakes not replying',
#  'Guy: Whenever you like',
#  "Guy: I'm playing video games",
#  "Mema Nackasha: 3 mins into my new book and I'm obsessed",
#  "Mema Nackasha: Let's go on a tour to North Korea ok xx",
#  'Guy: Eating your cheese and biscuits cos am poor',
#  'Guy: Where are you going on Feb? 😊',
#  'Guy: In*',
#  'Mema Nackasha: The Phil app',
#  'Mema Nackasha: Philippines !!',
#  'Mema Nackasha: £260 return :)',
#  'Mema Nackasha: How exciting is that',
#  "Guy: Hahaha that's amazing?!",
#  'Guy: I totally forgot haha',
#  'Mema Nackasha: Hahahaha',
#  'Mema Nackasha: I knowwwww I cannot wait !',
#  'Guy: How long for?',
#  'Mema Nackasha: 2 weeks',
#  "Guy: That's awesome!",
#  'Guy: lol you were loving the abs last night',
#  'Mema Nackasha: Course I was',
#  "Mema Nackasha: They're ridiculous",
#  'Mema Nackasha: All chubby',
#  'Guy: Hahah',
#  'Guy: Yes v chubby',
#  'Mema Nackasha: Little babies',
#  'Mema Nackasha: You were definitely not loving me loving them',
#  'Mema Nackasha: So funny',
#  'Mema Nackasha: I was so entertained hahaha',
#  "Mema Nackasha: Also because I definitely didn't want to stop partying or go to sleep",
#  'Guy: Slash you were so horny, lying between 2 solid 9s',
#  'Mema Nackasha: 10s',
#  'Mema Nackasha: Best looking boys on the planet',
#  'Mema Nackasha: Yeah fair',
#  "Mema Nackasha: I got smashed I really didn't mean to be drunk haha",
#  'Guy: Hahahaha your dad',
#  'Mema Nackasha: I miss the abs',
#  'Guy: Hahaha cheeky',
#  'Guy: I miss the bewbs',
#  'Mema Nackasha: U r',
#  'Mema Nackasha: Hahaha',
#  'Guy: Always',
#  'Mema Nackasha: I forgot how fun abs are',
#  'Mema Nackasha: Chubby abs',
#  'Guy: Oh shush i was curled up',
#  "Guy: They're hard",
#  'Mema Nackasha: No I mean each ab is chubby',
#  'Mema Nackasha: Not that you are chubby',
#  "Mema Nackasha: You've never been chubby",
#  "Mema Nackasha: They're just all plump and lovely",
#  'Mema Nackasha: Hahahaa',
#  'Guy: Same with bewbs!',
#  'Mema Nackasha: Yes',
#  "Guy: Didn't get to feel yours tho!",
#  "Mema Nackasha: Well that's cos you didn't want to",
#  'Mema Nackasha: Jake was busy touching my ass while I was feeling your abs',
#  'Guy: Hahahha',
#  'Mema Nackasha: Ridiculous tripod behaviour',
#  "Guy: Didn't get a good chance!",
#  "Mema Nackasha: I'm googling abs",
#  'Guy: Yeah tripod antics',
#  'Guy: 😂',
#  'Mema Nackasha: Hahahhahaaa',
#  "Mema Nackasha: Well what's mine is yours",
#  'Guy: You wish!',
#  'Mema Nackasha: Abs and traps',
#  'Mema Nackasha: 👅',
#  "Guy: Yeah that's basically what I look like",
#  'Guy: With some good lighting',
#  'Mema Nackasha: Yep',
#  'Guy: Boom',
#  'Mema Nackasha: Fuckin elllll',
#  "Guy: That's on FB!",
#  'Mema Nackasha: I know',
#  'Mema Nackasha: But',
#  'Mema Nackasha: Fuckin ellll',
#  'Guy: Hahaha 😊',
#  'Guy: Hahahah!',
#  "Guy: I've shown you mine...",
#  "Mema Nackasha: They're huge",
#  'Mema Nackasha: Looool',
#  'Guy: Ahaha epic!',
#  'Guy: Friends for lyfe',
#  'Mema Nackasha: *best',
#  'Guy: Hahah that was a fun day',
#  'Guy: And that was an awesome cocktail!',
#  'Mema Nackasha: It was !!',
#  "Mema Nackasha: You're so handsome and cute",
#  'Mema Nackasha: Dawwww',
#  'Mema Nackasha: ❤❤❤❤❤❤❤😂😂',
#  "Mema Nackasha: I've got so much love to give its tiring",
#  'Mema Nackasha: Look at that little face oyyyyyy',
#  'Guy: Crows feet lol',
#  "Guy: I'm gonna have such smile wrinkles when I'm older",
#  "Mema Nackasha: I love them so much it's the cutest thing ever",
#  'Guy: Hahaha I am not cute! 😡',
#  'Mema Nackasha: Plus I have them too',
#  'Mema Nackasha: Omg so cute',
#  'Mema Nackasha: Edibly cute',
#  'Guy: Omg how much do you fancy me right now',
#  'Mema Nackasha: 100',
#  "Mema Nackasha: It's all cos of the abs really",
#  'Guy: Haha!',
#  'Guy: Good thing there are a bunch of pics on FB for you fap to?',
#  'Mema Nackasha: And maybe your face too, you do have an excellent face',
#  "Mema Nackasha: Yeah there's enough material dw xx",
#  'Guy: Too kind',
#  'Guy: Imagine if you Jake and I had a threesome?',
#  'Mema Nackasha: Nope',
#  'Mema Nackasha: I have thought about this yeah',
#  'Mema Nackasha: My dream is to marry you both',
#  'Mema Nackasha: And be best friends who get to live together and love you both forever and ever',
#  'Guy: But not for us to DP you',
#  'Guy: Nawwww that would be amazing',
#  'Mema Nackasha: And then have perfect babies with your perf genes',
#  'Mema Nackasha: Or maybe just adopt loads',
#  "Guy: We're like When Harry met Sally but with tripod",
#  "Mema Nackasha: And then we'll have an extra big double bed like my one at home",
#  'Mema Nackasha: And I can be cuddled all the time',
#  'Guy: Hahahahaha',
#  "Mema Nackasha: And 2 husbands means I'll maybe get enough attention ya know I need loads of attention",
#  'Guy: But we have needs too!',
#  'Mema Nackasha: BUT 2 penises is too many penises in one go',
#  "Mema Nackasha: Waaaaaait what needs could you have that I couldn't cater to",
#  "Mema Nackasha: I'd do anything for you",
#  'Mema Nackasha: I already dote on you',
#  'Mema Nackasha: So WHAT MORE DO YOU NEED',
#  'Guy: Hahahaha',
#  'Guy: This is such a weird fantasy',
#  'Guy: I love it',
#  'Mema Nackasha: I told jake the other day',
#  'Mema Nackasha: and he said "u wish"',
#  'Guy: Hagahaaaa',
#  "Mema Nackasha: I mean I'm already obsessed with both of you so it'd be the best life ever",
#  "Mema Nackasha: We'd laugh all the time",
#  'Mema Nackasha: Go on fun trips',
#  "Mema Nackasha: I'd get to hold hands with both of you",
#  "Mema Nackasha: It's just an amazing dream",
#  'Guy: Haaaaa',
#  'Guy: I think Jake and I would need side-girls',
#  'Mema Nackasha: FOR WHAT',
#  'Mema Nackasha: I HAVE ENOUGH LOVE FOR YOU ☹️☹️',
#  'Guy: For BJs and stuff!!',
#  "Mema Nackasha: Mate I'll remember how to do that shit and we'll all be fine",
#  "Mema Nackasha: Too much I'm dying",
#  'Guy: Hahahaaa',
#  "Mema Nackasha: We'd have a puppy and it'd be the only other thing you'd love as much as me",
#  'Guy: Yes an Italian greyhound perhaps!',
#  "Mema Nackasha: We'd call him Zeus but I'd call him zoozoo",
#  "Mema Nackasha: And we'd live in Regent's Park and brunch on the weekends and everyone would know us as the unconventional triple (couple) who live the most perfect lives together",
#  "Mema Nackasha: Nobody loves me as much as you 2 do, I was telling jake this, I feel so safe and loved and even sexy and smart and beautiful and lovely and nice because you've both empowered me so much",
#  'Mema Nackasha: So',
#  "Mema Nackasha: That's the dream",
#  'Guy: Good!',
#  'Guy: You are all of those things',
#  'Guy: FOr some reason the other day I was thinking about what would happen if you died',
#  'Guy: And I reckon like 900 people would come to your funeral',
#  'Guy: And it would be so much worse than anyone else I know dying',
#  'Guy: From a general perspective',
#  "Mema Nackasha: Omg you kill me seriously you're the best human ever",
#  "Mema Nackasha: Well if you died that'd be the end of my life",
#  'Mema Nackasha: So',
#  "Mema Nackasha: Don't die",
#  'Mema Nackasha: Also',
#  "Guy: Ok let's all not die",
#  "Guy: Haha you love backs don't you",
#  'Mema Nackasha: Yes :D',
#  "Mema Nackasha: I haven't fancied you for ages",
#  'Mema Nackasha: I forgot how hot you are',
#  'Mema Nackasha: But',
#  'Guy: Hahahaha',
#  'Mema Nackasha: Why were you thinking of me dying',
#  'Mema Nackasha: Did you get sad at the thought',
#  'Guy: I got so sad',
#  'Guy: It would actually be so worse',
#  'Guy: Just thinking of the sheer number of people who would be devastated',
#  'Guy: Like 100 of your family members',
#  'Guy: Your priest',
#  'Guy: Friends in about 8 different countries',
#  'Guy: And companies thatyouve worked for',
#  'Guy: Etc',
#  'Mema Nackasha: 😱',
#  'Mema Nackasha: 😳',
#  "Guy: And you're only 24",
#  "Mema Nackasha: I don't understand why and how you and jake see me as this lil angel",
#  'Mema Nackasha: I feel so so special',
#  'Mema Nackasha: Like a rare gem',
#  "Mema Nackasha: But I'm just another drop in the ocean",
#  "Guy: Everyone thinks you're a little angel",
#  'Mema Nackasha: Another normal human with people who love her',
#  'Mema Nackasha: Like all the other people',
#  "Guy: We're just the only ones who you care to be with",
#  "Mema Nackasha: I like lots of my other friends too but I'm just always happiest when my babies are around",
#  "Guy: We're not babies!",
#  'Mema Nackasha: My babes ❤',
#  "Guy: Let's get back to you fancying me",
#  "Mema Nackasha: Hahaha it's well fun",
#  'Mema Nackasha: I fancied jake a bit on Thursday evening',
#  'Mema Nackasha: And now you tonight',
#  "Guy: You're so flippant lol",
#  "Mema Nackasha: That's my middle name",
#  "Mema Nackasha: It's mental",
#  'Guy: Want me to send you another pic',
#  'Mema Nackasha: YES',
#  'Mema Nackasha: 😄',
#  'Mema Nackasha: Yalla',
#  "Guy: Sorry couldn't find the one I was looking for",
#  'Guy: It was super sexy',
#  'Mema Nackasha: 😩',
#  "Mema Nackasha: I'm so far down on your Facebook I think I need to stop",
#  "Mema Nackasha: You're a bit young for me down there",
#  'Guy: Imagine if I just sent you a dick pic hahaha',
#  'Guy: Would be so rood',
#  'Mema Nackasha: Ahahhahahaaa',
#  'Guy: Like yeah so sexy',
#  "Mema Nackasha: I feel like we have no boundaries so I wouldn't mind",
#  'Guy: Yeah 😂',
#  "Mema Nackasha: You and Jake can't ever do any wrong",
#  'Mema Nackasha: So whatever happens is fine with me pmsl',
#  "Guy: That's the safe for work version",
#  'Mema Nackasha: Fuuuuuuuck',
#  "Mema Nackasha: You're like Jesus but real",
#  'Guy: Hahahaha',
#  "Mema Nackasha: I think I've decided",
#  'Mema Nackasha: For my bday',
#  "Mema Nackasha: I'm gonna take the tripod on a lil trip",
#  'Mema Nackasha: Or forward slash next year for our 10 year anniversary maybe',
#  'Guy: Cool!',
#  'Guy: Where to?',
#  'Mema Nackasha: Maybe Malta',
#  'Guy: Interesting',
#  'Guy: I have friends in Malta',
#  'Guy: Well, friend',
#  "Mema Nackasha: It needs to be somewhere I've never been and I've never been there",
#  'Mema Nackasha: Or Slovenia',
#  'Mema Nackasha: Lake bled',
#  "Mema Nackasha: It'll be amazing",
#  'Guy: Awesome!',
#  'Guy: Excited already',
#  'Mema Nackasha: Me too',
#  'Mema Nackasha: Maybe we could take a couple of days off in like July and do a super long weekend',
#  "Mema Nackasha: I'll think about t",
#  'Guy: I could do that',
#  'Mema Nackasha: 😊',
#  'Guy: Are you gonna propose to us?',
#  'Mema Nackasha: This is all only so that I get to see those abs in trunks',
#  'Mema Nackasha: Well you ruined it now',
#  'Guy: Omg if you want to see more just ask',
#  "Guy: If Jake weren't there I definitely would have been tempted last night",
#  'Mema Nackasha: Omg stop',
#  'Mema Nackasha: I forgot about abs',
#  'Mema Nackasha: I stopped liking them for ages',
#  'Mema Nackasha: But now',
#  'Mema Nackasha: They were in my hands and I loved them again',
#  'Guy: Another minute and you would have got me hard AF as well',
#  'Mema Nackasha: REALLY',
#  'Mema Nackasha: I thought you were just batting me off cos I was being annoying',
#  'Guy: Hahahaha',
#  'Guy: Nahh',
#  'Guy: I am human',
#  'Mema Nackasha: Look like a god to me',
#  'Guy: You want moar doncha',
#  'Mema Nackasha: Yes',
#  'Mema Nackasha: This is my favourite topic',
#  'Mema Nackasha: Of the evening',
#  "Mema Nackasha: Guy's abs",
#  'Guy: Hahaha tomorrow youll have forgotten',
#  "Mema Nackasha: When we get married they'll also be mine 🤔",
#  'Mema Nackasha: Yeah probs',
#  "Mema Nackasha: I'll go back to fancying ash at work",
#  'Mema Nackasha: Or maybe my gf 🙄',
#  'Guy: Hahaha',
#  "Guy: Good thing we weren't alone last night then",
#  'Mema Nackasha: Are you in an open relationship guygeous ?',
#  'Guy: You wish',
#  'Mema Nackasha: Just out of interest',
#  'Guy: No',
#  "Mema Nackasha: I mean I don't care cos I can have you WHENEVER I WANT",
#  'Mema Nackasha: Jk jk',
#  "Guy: Which is one of the reasons why it's a good thing we weren't alone last night",
#  'Mema Nackasha: 👅',
#  'Mema Nackasha: Pmsl',
#  "Mema Nackasha: I've sent that tongue emoji a million times today",
#  'Guy: Hahaha to whom else??',
#  'Mema Nackasha: U',
#  'Guy: Flirt',
#  'Mema Nackasha: With your abs',
#  'Mema Nackasha: 👅👅👅👅👅',
#  "Mema Nackasha: I don't flirt",
#  'Guy: Sure',
#  "Mema Nackasha: I don't know how to",
#  "Mema Nackasha: I'm just nice",
#  'Guy: Yeah me too',
#  "Guy: But I'm not even nice",
#  "Mema Nackasha: No you're motherfucking charming as fuck",
#  'Mema Nackasha: I was telling jake that',
#  'Mema Nackasha: Jake makes me feel like the sexiest girl on the planet without even saying anything',
#  "Mema Nackasha: And you're so charming that you say things that melt me all the time",
#  'Guy: Nawwww',
#  "Guy: I'm definitely not charming with anyone else",
#  'Guy: Seriously haha',
#  "Mema Nackasha: We talked about it as we walked through Regent's Park",
#  "Mema Nackasha: I don't believe that !!!",
#  "Mema Nackasha: When we were at school I remember people like Zoe Lewin etc asking me what I'd done to you because you apparently had this massive soft spot for me",
#  'Mema Nackasha: But everyone liked you and fancied you',
#  "Guy: For reals, I'm only a bit charming with friends",
#  'Mema Nackasha: So I assumed that you must be the same with everyone',
#  'Guy: Hahaha Mema',
#  "Mema Nackasha: But since we've grown up you have so many people who adore you",
#  "Mema Nackasha: So I asssumeeeee you're pretty charming with them too",
#  "Guy: I get so little attention from women, it's always been such a shock when you say this stuff",
#  "Guy: It's so nice",
#  "Mema Nackasha: E.g. Your uni mates, like I'm sure you're the same with Lottie for example",
#  "Guy: Yeah that's true, with my girls from uni",
#  'Mema Nackasha: See, you empower us',
#  "Mema Nackasha: And cos you're such a genuinely amazing person",
#  'Mema Nackasha: Clever and sweet AND handsome',
#  "Mema Nackasha: It's extra amazing that lovely things come from you",
#  'Guy: Thank you 😘',
#  "Mema Nackasha: And you don't get little attention, you probably just dont realise the attention you get",
#  "Guy: I'm actually really insecure about women",
#  "Guy: And it's gotten worse as I've gotten older",
#  'Mema Nackasha: For example, on the train rach said "Mema\'s boys are the nicest guys ever, plus guy is really fit" and then lowri said "yeah I thought that when I met him, but I fancy jake now"',
#  'Mema Nackasha: So like',
#  "Mema Nackasha: That's hot girls fancying you",
#  "Mema Nackasha: I don't know how you could possibly be insecure about women, you're so desirable, every tiny bit of you is derivable",
#  'Mema Nackasha: Desirable',
#  'Mema Nackasha: lol derivable',
#  'Mema Nackasha: Wish I was next to you I wanna give you a cuddle now (and not just for the abs)',
#  'Mema Nackasha: WHERE HAVE YOU GONE',
#  'Guy: Sorry getting ready for bed',
#  'Guy: Getting naked etc',
#  'Guy: Basically I can pinpoint the issue',
#  'Guy: After many years of thinking about it',
#  'Mema Nackasha: Stay naked',
#  'Mema Nackasha: And tell me what it is',
#  'Guy: Women are just too subtle',
#  'Guy: And they want the guy to make the first move',
#  "Guy: And they're so stand offish that they wouldn't even smile in the street to me",
#  'Guy: Like I can count how many times a stranger woman smiled at me',
#  'Guy: 3 times',
#  'Guy: I remember them specifically haha',
#  'Guy: How sad is that',
#  "Mema Nackasha: you don't remember me !!!!",
#  'Mema Nackasha: Well',
#  'Mema Nackasha: Nobody smiles in London',
#  'Guy: Yeah I missed that!',
#  'Guy: Hahaha',
#  'Mema Nackasha: I smile at everyone',
#  'Mema Nackasha: The big issue man on a Monday morning called out: "first smile of the day, thank you lovely lady in the yellow coat" and that was my proudest moment haha',
#  "Guy: So yeah I guess you must think I'm a bit like Rachel",
#  "Guy: Hahaha that's a nice story 😊",
#  "Guy: You're the nicest",
#  'Mema Nackasha: Women are subtle and do want men to make the first move buuuuut are you scared of getting knocked back?',
#  "Mema Nackasha: Yeah you're literally a god",
#  'Mema Nackasha: Every aspect of you',
#  'Mema Nackasha: So I cannot understand how you could feel insecure ever',
#  "Guy: Well it's not necessarily like I want to actually chat someone up and go on a date",
#  "Guy: It's more like, I just want SOMETHING",
#  "Mema Nackasha: I used to be insecure but because of you and jake I don't really care about my insecurities anymore, nice work 😘😘😘😘",
#  'Guy: Some affection, some sign that they actually see me',
#  'Mema Nackasha: Hmmmmmm',
#  'Mema Nackasha: Owwwww',
#  "Mema Nackasha: That's the saddest thing you've ever said",
#  "Mema Nackasha: But you're a head turner like you are very gorgeous",
#  "Guy: Yeah and it's getting worse as I get older",
#  'Mema Nackasha: How !!!!',
#  'Guy: Just',
#  "Mema Nackasha: You've gotten way better as you've got older",
#  "Mema Nackasha: You're like wine",
#  "Guy: Like I'm not more attractive than I was 5 years ago",
#  'Guy: Hahaha',
#  "Mema Nackasha: You're the same attractiveness",
#  "Mema Nackasha: But you're nicer I think",
#  'Guy: I hope so!',
#  "Mema Nackasha: I think you've blossomed into being a perfect human",
#  "Guy: Anyway thanks, you don't want to hear this lol",
#  'Mema Nackasha: Like you were already perfect',
#  "Mema Nackasha: But now you're extra nice too",
#  "Mema Nackasha: Wait why don't I want to hear this ???",
#  'Guy: Negative Nancy !',
#  "Mema Nackasha: You're not negative",
#  "Mema Nackasha: You're a ray of sunshine",
#  "Mema Nackasha: You're allowed to feel down about one thing one time",
#  "Mema Nackasha: Don't be hard on yourself silly billy",
#  "Mema Nackasha: Plus I'm whiney 109272622 times a week and you just maintain my high maintenance self and do it very well too",
#  'Guy: Hahaha',
#  "Guy: I don't even do anything",
#  'Mema Nackasha: 😘',
#  'Mema Nackasha: I dunno you do lots for me',
#  'Guy: Well gud',
#  'Mema Nackasha: I feel like everyone seems to be in relationships now',
#  'Mema Nackasha: And people like search for the person they want, like their ideal human, via dating apps and websites and stuff',
#  'Mema Nackasha: And then maybe forget to be nice to all the humans irl',
#  'Mema Nackasha: I mean I smile and everyone and nobody ever smiles back at me',
#  "Mema Nackasha: But I don't really mind",
#  'Mema Nackasha: Just for you to gauge you know',
#  'Guy: Yeah',
#  "Mema Nackasha: Like it's easy to smile back at someone",
#  'Guy: Thanks bbs',
#  "Mema Nackasha: But people don't",
#  'Mema Nackasha: I always get taken aback when someone does',
#  'Mema Nackasha: Haha',
#  'Guy: That is rood',
#  'Mema Nackasha: London commuters ffs',
#  'Mema Nackasha: It is !!',
#  'Guy: Yep!',
#  'Mema Nackasha: Anyway you always have a girlfriend',
#  "Mema Nackasha: You're always on the market for 2.6 minutes before someone snatches you right up",
#  'Guy: Yep',
#  "Guy: I kind of don't want a girlfriend",
#  'Guy: And I do',
#  'Guy: I want both',
#  'Mema Nackasha: ME TOO',
#  'Mema Nackasha: Omfg',
#  "Mema Nackasha: I don't want to be in a relationship",
#  'Mema Nackasha: But I want constant attention and security and love',
#  'Mema Nackasha: I.e. A partner',
#  "Guy: Glad I'm not the only one",
#  'Guy: Haha!',
#  'Mema Nackasha: THIS IS WHY I FEEL LIKE IM GONNA DIE ALONE',
#  'Mema Nackasha: because I change my mind so much',
#  "Mema Nackasha: You're not flippant like me though guy",
#  "Mema Nackasha: You're stable and wonderful",
#  "Guy: You're gonna find someone who constantly surprises you",
#  'Guy: And who you really worship',
#  'Guy: I reckon',
#  'Mema Nackasha: I worship everyone',
#  'Mema Nackasha: I worship you !!!!',
#  'Mema Nackasha: And jakey',
#  "Mema Nackasha: Hence why I'm gonna marry you both",
#  'Mema Nackasha: Ok',
#  'Guy: Yeah someone great like us',
#  'Mema Nackasha: Or maybe just you xx',
#  'Mema Nackasha: Why do you have to be 2 people',
#  'Mema Nackasha: How annoying for me',
#  'Guy: Haaaaa',
#  'Guy: Twopod',
#  'Mema Nackasha: 😄',
#  'Mema Nackasha: Hahahaa',
#  'Mema Nackasha: Is Annie the one',
#  'Guy: No',
#  'Guy: But I do really like her',
#  'Mema Nackasha: Are you in love',
#  'Guy: Yes',
#  'Mema Nackasha: 😊',
#  "Guy: But she's going to law school and stuff",
#  'Mema Nackasha: But if she was in London for good',
#  'Mema Nackasha: Could she be the one',
#  "Guy: I don't really think so",
#  "Mema Nackasha: It's crazy cos I feel like she isn't either",
#  "Mema Nackasha: Also I feel like marie isn't my one",
#  "Mema Nackasha: We're in similar boats atm I think",
#  'Guy: Also I don\'t really believe in "the one"',
#  "Mema Nackasha: No that's dumb",
#  'Mema Nackasha: But I mean I think you can be with someone and feel like you could happily be with them forever',
#  'Mema Nackasha: And there are other ones, who are just the one for now',
#  'Mema Nackasha: Still wanna cuddle you',
#  'Mema Nackasha: mate',
#  'Guy: Yeah I get you',
#  'Mema Nackasha: Gala removed me on fb',
#  'Mema Nackasha: Looool',
#  'Mema Nackasha: I thought she kind of liked me !!!!',
#  "Guy: Hahah I haven't been friends with her for a while",
#  'Mema Nackasha: Did she remove you?',
#  'Guy: Yeah. I probably came up on your profile',
#  'Guy: Gala and I had such a flawed relationship, but I loved her more intensely than anyone',
#  'Guy: Like the intensity of emotion was like triple what I ever feel about anything now',
#  'Guy: Even Guido',
#  'Guy: Also more than with Kathryn',
#  'Mema Nackasha: The whole time ???',
#  'Mema Nackasha: Even guido omg I love you',
#  "Mema Nackasha: I mean, didn't the intensity die down after a year or so?",
#  'Mema Nackasha: I hope you find that intensity again guygeous',
#  "Mema Nackasha: But you know it's only because painful love feels stronger than good love",
#  'Mema Nackasha: I think',
#  "Mema Nackasha: Wish you'd been with me and jake all week, we talked about this too haha",
#  'Guy: It did die down yeah',
#  "Guy: But it's like",
#  'Guy: If I i through the rest of my life not feeling that again',
#  "Guy: I'll be seriously disappointed",
#  'Guy: If I go*',
#  "Mema Nackasha: You're still young",
#  "Mema Nackasha: You'll feel it again",
#  'Guy: Hope so',
#  'Mema Nackasha: But it was pain',
#  "Mema Nackasha: If you have a spare evening this week (I don't think that exists in your life) then I wanna come over and cuddle you",
#  "Mema Nackasha: I feel like I haven't looked after you much",
#  'Mema Nackasha: My little babe',
#  'Guy: Hahah okie',
#  "Guy: You just wanna see the abs don't you",
#  'Mema Nackasha: *touch',
#  'Guy: And more',
#  'Guy: 💦',
#  'Mema Nackasha: Pmsl',
#  "Mema Nackasha: You're getting way too excited sir",
#  'Mema Nackasha: I just wanna hold those chubby abs',
#  'Mema Nackasha: Also',
#  "Mema Nackasha: You're huge",
#  'Mema Nackasha: So is jake',
#  "Mema Nackasha: So it's so nice to be cuddled hahaa",
#  'Guy: Nawwww',
#  'Guy: She is lovely 😊',
#  "Mema Nackasha: Love her so much she's my favourite female friend",
#  'Mema Nackasha: Back to you',
#  'Guy: Enough of me',
#  'Mema Nackasha: Hahahaha',
#  "Mema Nackasha: There's so much of you",
#  'Mema Nackasha: 👅👅👅',
#  'Mema Nackasha: 😂😂😂',
#  'Mema Nackasha: I should be put down',
#  'Guy: 👅 💦',
#  'Mema Nackasha: Hehehe',
#  "Mema Nackasha: But I can't die",
#  'Mema Nackasha: Remember you have to carry my coffin',
#  'Guy: Yes I remember',
#  'Guy: How detailed is your will?',
#  'Guy: Or whatever those instructions are?',
#  'Mema Nackasha: I need to rewrite it',
#  'Mema Nackasha: I wrote the instructions before I went to uni',
#  'Mema Nackasha: Like in my gap year or something',
#  'Mema Nackasha: But then my laptop died',
#  "Mema Nackasha: And my dad's friend unpicked all my info off of it",
#  'Mema Nackasha: And interpreted the "if I\'m dead" as a suicide note lols oops',
#  "Mema Nackasha: But I was pretty in love with you back then except I think it was the time we werent really friends pmsl so I can imagine it's some quick cringe note for you",
#  'Mema Nackasha: I mean I had a little paragraph for all the people I loved',
#  'Mema Nackasha: But',
#  'Mema Nackasha: Those people have changed',
#  'Mema Nackasha: For example at the time I was so close to Ross and James and the year above boys',
#  'Guy: What do the paragraphs say?',
#  'Guy: Oh yeah!',
#  "Mema Nackasha: Who I now haven't spoken to for years and years",
#  "Mema Nackasha: I can't really remember",
#  "Mema Nackasha: It'd just be like a mini thank you",
#  'Mema Nackasha: Also instructions were who should carry my coffin',
#  'Mema Nackasha: And that whatever you do with me, bunny must come with me',
#  "Mema Nackasha: Don't even know if I still have it",
#  'Guy: Haaaa',
#  'Guy: That is funny',
#  'Guy: And morbid',
#  "Mema Nackasha: Well I'm just always scared of leaving people I love",
#  "Mema Nackasha: I'm not scared of dying",
#  "Mema Nackasha: But I'm scared of what'll happen to my closest humans",
#  'Mema Nackasha: I dunno',
#  "Mema Nackasha: I don't think about it anymore",
#  'Mema Nackasha: But I always used to worry about it',
#  "Guy: You're sweet",
#  'Guy: Too sweet!',
#  'Mema Nackasha: You are',
#  'Mema Nackasha: I need to do my will',
#  'Mema Nackasha: Atm it just says give everything to Lolo',
#  'Guy: Which is probably good no?',
#  'Mema Nackasha: Yes but what if he dies with me',
#  'Mema Nackasha: I want some details',
#  "Mema Nackasha: If my family die I'll leave you and Jake most of the rest of my things",
#  "Mema Nackasha: I'll actually maybe just leaving you my savings account to pay off that stupid astronaut loan",
#  "Mema Nackasha: I'll make a note I need to do that",
#  'Mema Nackasha: Write my will properly',
#  'Guy: Hmmm so now I just have to take care of Louis and you',
#  'Guy: Lewis',
#  'Guy: Lewie',
#  'Mema Nackasha: :)',
#  'Guy: And Jake',
#  "Mema Nackasha: I'll leave him some things too",
#  "Mema Nackasha: That's why I'm gonna take us away",
#  'Mema Nackasha: May as well enjoy the money with you guys',
#  'Guy: Woo!',
#  "Mema Nackasha: Rather than dying and then you'd be too depressed to go to Slovenia without me",
#  'Mema Nackasha: Hahahaa',
#  "Guy: You're not gonna die for like 65 years",
#  "Mema Nackasha: I literally feel like I'll be the oldest person in the world one day",
#  'Mema Nackasha: I feel like that',
#  "Mema Nackasha: Do you feel like you'll live till you're old",
#  'Guy: No',
#  'Mema Nackasha: Love you',
#  'Guy: Love you too 😘',
#  'Mema Nackasha: 😘😘😘😘😘',
#  'Guy: Are you done fancying me now?',
#  'Mema Nackasha: Yep',
#  'Mema Nackasha: Actually',
#  "Mema Nackasha: I just looked at our media on whatsapp and it's all abs",
#  'Mema Nackasha: Hahaha',
#  'Mema Nackasha: The tripod has had such an incestual week',
#  'Guy: Hahaha!',
#  'Mema Nackasha: 😘😘😘😘',
#  'Mema Nackasha: "It\'s difficult to hate you because you\'re so bloody nice" ',
#  "Mema Nackasha: -Mema's colleagues 2k17",
#  'Mema Nackasha: 😂😂😂',
#  'Guy: Hahahahaha',
#  'Mema Nackasha: JAKE IS GOING FOR A DRINK WITH EVA THIS WEEKEND !!!',
#  'Mema Nackasha: Maybe',
#  'Mema Nackasha: SATURDAY NIGHT',
#  'Guy: Busy Saturday night',
#  'Guy: Free on Friday like we already planned!',
#  'Guy: Hahaha',
#  'Guy: Oh right',
#  'Guy: Yeah!',
#  'Mema Nackasha: Have you heard what happened to jake',
#  'Mema Nackasha: He might not come tonight looool',
#  'Guy: No?!',
#  'Guy: Too many chillis?',
#  'Mema Nackasha: He did the chilli challenge',
#  "Mema Nackasha: Didn't make it to work",
#  "Mema Nackasha: Cos he's fucked his tummy up",
#  'Guy: Ohhhh shiiiiitttttt',
#  'Guy: Is he ok??',
#  'Mema Nackasha: I think so',
#  "Mema Nackasha: But he's in pain",
#  'Guy: So is it just me coming tonight?',
#  'Mema Nackasha: Sam and Luke',
#  'Mema Nackasha: And lowri',
#  'Mema Nackasha: Miri and her mate',
#  'Mema Nackasha: And I think jake will come',
#  'Guy: Oh right!! I thog it it was just tripod',
#  'Mema Nackasha: I invited you guys specifically',
#  'Mema Nackasha: Because',
#  'Mema Nackasha: Lowri asked to stay at mine for the weekend',
#  "Mema Nackasha: and I didn't really fancy being alone with her",
#  "Mema Nackasha: So then I invited rach but she cancelled last night as she's working lates",
#  'Mema Nackasha: But I asked you and jake to come because I love you most',
#  "Mema Nackasha: And then Sam was really gutted he missed out on rach's bday so I invited him",
#  'Mema Nackasha: And he asked if Luke could come',
#  'Mema Nackasha: So I was like fuck it',
#  'Mema Nackasha: Everyone can come whatever',
#  "Mema Nackasha: But it's not a party",
#  "Mema Nackasha: Eva hasn't replied to jake 🤔",
#  'Guy: Oh no!!',
#  'Guy: Is he still at home or is he waiting for her out??',
#  "Mema Nackasha: He's at home",
#  'Mema Nackasha: He text her at 4.30 saying shall we meet at 8',
#  "Mema Nackasha: And he wasn't sure if the message delivered",
#  'Mema Nackasha: She was on whatsapp at 6.30',
#  'Guy: Do you think I should text her or anything?',
#  "Mema Nackasha: So he whatsapped her saying I don't know if my messages have delivered",
#  "Mema Nackasha: And he hasn't heard anything still",
#  'Mema Nackasha: Maybe not just yet',
#  "Guy: That's annoying",
#  "Mema Nackasha: Let's wait till 8.30",
#  "Mema Nackasha: Yeah it's",
#  'Mema Nackasha: However he did leave it quite late',
#  'Mema Nackasha: But still',
#  'Guy: I like Eva',
#  'Mema Nackasha: Me too',
#  'Mema Nackasha: But I feel a but coming along',
#  "Guy: But I have a feeling she's not the kind of person who I want me friends to be with",
#  'Guy: For their sakes',
#  'Guy: Based on some of the things Annie has told me',
#  "Guy: But I'm not sure about that",
#  'Mema Nackasha: Hmm',
#  'Mema Nackasha: Well',
#  'Mema Nackasha: If she messes jake around I will be very angry',
#  'Guy: Yeah me too',
#  'Mema Nackasha: Love u',
#  "Mema Nackasha: also thank you for my prosecco and toblerone you're really my fave",
#  'Mema Nackasha: (Marginally)',
#  'Guy: Hahaha',
#  'Mema Nackasha: Still nothing',
#  'Mema Nackasha: Should he call her',
#  "Guy: Urgh that's so rood of her",
#  'Mema Nackasha: ☹️',
#  'Mema Nackasha: SO ROOD',
#  'Guy: Did you mean to write that in tripod',
#  'Mema Nackasha: Yes',
#  'Mema Nackasha: I told him we need to discuss things with you',
#  'Mema Nackasha: As you know her',
#  'Mema Nackasha: Btw please think again about me giving u the monies',
#  'Mema Nackasha: We did it last time and it worked really well I thought',
#  "Mema Nackasha: And I'd love to help you out",
#  "Mema Nackasha: And it wouldn't effect me in the slightest",
#  'Mema Nackasha: And just think about it',
#  "Mema Nackasha: I'll keep offering",
#  'Guy: Thanks',
#  "Guy: But I was telling you so you'd understand when I don't come to some events",
#  'Mema Nackasha: I understand baby boy',
#  "Mema Nackasha: But also understand that like I'd do anything for Lolo, the same applies for you",
#  "Mema Nackasha: I'd give you allllllll my monies if you needed them",
#  "Mema Nackasha: And also I'd rather you have fun and don't be stressed about money when I can help out",
#  'Guy: Srsly what was up with Jake?',
#  'Guy: Today and last night',
#  'Mema Nackasha: He says he was feeling anxious from the big crowds today',
#  'Mema Nackasha: I even asked if it was anything to do with me or you',
#  'Mema Nackasha: And he said absolutely not',
#  'Mema Nackasha: He did go back to normal when we sat down in cafe rouge',
#  'Mema Nackasha: \u200eMissed voice call',
#  'Mema Nackasha: Flat hunting has begun btw',
#  "Mema Nackasha: I'm looking around Camden",
#  "Mema Nackasha: It'll obvs take a little while",
#  "Mema Nackasha: But you'll be living with me soon bébé",
#  "Mema Nackasha: Also I told my mum and she's so upset and she said please give the money to guy and tell him he doesn't need to pay us back if he can't or he can take as long as he wants to pay back",
#  'Mema Nackasha: Soooooooo',
#  "Mema Nackasha: But Camden is cool isn't it !!!",
#  "Mema Nackasha: And then we'll northern line to work in like 15 mins",
#  'Guy: Thanks bb',
#  'Guy: Honestly, there is no one to blame but myself',
#  'Guy: Even though I imply otherwise',
#  'Mema Nackasha: No but u r mine',
#  "Mema Nackasha: What's mine is yours xx",
#  'Guy: Hahahah',
#  'Mema Nackasha: U and Jakey',
#  'Mema Nackasha: 😃',
#  'Guy: That would be amazing',
#  "Guy: But please don't let anyone but yourself be a factor in the decision",
#  'Mema Nackasha: Which bit',
#  'Mema Nackasha: The flat or giving you 4 grand',
#  'Guy: The flat',
#  "Guy: And don't worry about the money, I'm gonna borrow it from my mum",
#  "Mema Nackasha: I don't know which other opinions would change anything",
#  'Mema Nackasha: I wanna live with my best pal :)',
#  'Mema Nackasha: And as jake already has a flat',
#  'Mema Nackasha: I HAVE to choose you',
#  'Mema Nackasha: Duh',
#  'Guy: Dope 😊',
#  'Mema Nackasha: Mwah',
#  'Guy: Cutie',
#  "Guy: That's great haha",
#  'Guy: I should have done that',
#  'Mema Nackasha: Yeah should have got the abs out yep',
#  'Guy: Always',
#  'Guy: Nice Prof pic btw!',
#  'Mema Nackasha: Hahaha',
#  'Mema Nackasha: Thanks boo',
#  'Mema Nackasha: I love it too',
#  'Mema Nackasha: My babies ❤❤❤',
#  'Mema Nackasha: Playing a game of "let\'s see how many animals we can see without going into the barbaric zoo"',
#  'Guy: Hahaha 😂',
#  'Mema Nackasha: 😃',
#  'Mema Nackasha: Btw which evening are you free this week for me and jake to come over and cook',
#  'Guy: Hmmm inviting yourself round eh?',
#  "Guy: It's not like we're married",
#  'Mema Nackasha: Jake said you said we could',
#  'Mema Nackasha: ... YET',
#  'Mema Nackasha: I dream of the day mr Robertson',
#  'Guy: No I said Jake could come',
#  'Guy: Jk how about Wednesday?',
#  'Mema Nackasha: O',
#  'Mema Nackasha: Phew',
#  'Mema Nackasha: PERFECT 😃',
#  "Mema Nackasha: Once I've had a lil bit of you I crave you more",
#  "Mema Nackasha: So now you're lumbered with me",
#  'Guy: Hahah',
#  "Guy: Why hasn't Jake been invited",
#  "Mema Nackasha: I'm just kidding of course he'll come",
#  "Guy: I didn't mean to say that",
#  "Guy: I meant why hasn't Jake been responding?",
#  "Mema Nackasha: Sometimes he doesn't sleep well and then he crashes at like 7pm when he gets home",
#  'Guy: That sucks',
#  "Guy: I couldn't do it",
#  "Mema Nackasha: Me either it's so horrendous poor thing lm",
#  'Guy: Wait so is Jake coming or not?',
#  "Mema Nackasha: Course he'll come",
#  'Mema Nackasha: I might stay over after',
#  'Mema Nackasha: Would that be ok',
#  'Guy: Yeah of course',
#  "Mema Nackasha: It's just an effort to get back to Camden",
#  'Guy: And go straight to work from mine?',
#  'Mema Nackasha: Thanks honeybunch',
#  'Guy: Noice!',
#  'Mema Nackasha: Yep yep :)',
#  'Mema Nackasha: So I can stay up and hang with you in the evening',
#  "Mema Nackasha: Or else I'd have to leave at like 10 to get home for 11 hahaa",
#  'Guy: Defo stay',
#  'Mema Nackasha: Promotion has been confirmed',
#  "Mema Nackasha: I'm scared",
#  "Mema Nackasha: I'm taking over the whole of the inside sales which means I'll be account manager for all 400 of our UK eTap customers",
#  "Mema Nackasha: Also I'm continuing my current role as well",
#  "Mema Nackasha: Which means that I'm doing 2 jobs basically",
#  'Guy: Hahaha',
#  'Mema Nackasha: And my targets are gonna increase but that means I can make so much more commission too',
#  'Mema Nackasha: training starts tomorrow',
#  'Guy: Dope!',
#  'Mema Nackasha: Scary',
#  "Guy: It's great that they are properly utilising your talent",
#  'Mema Nackasha: Yes they are lovely',
#  'Guy: Btw just a thought',
#  'Mema Nackasha: Is it that you love me',
#  'Guy: But perhaps it might be a little bit bad to talk about my incredible amazing body in front of people aka Jake?',
#  'Mema Nackasha: What why',
#  "Guy: Obv we have nothing to hide but it's the kind of thing you don't want to hear from the love of your life?",
#  "Mema Nackasha: I'm obsessed with both of you",
#  'Mema Nackasha: Oh',
#  'Mema Nackasha: But selfishly',
#  "Mema Nackasha: This is the exact kind of thing I don't want to have to think about",
#  "Mema Nackasha: We're not together",
#  "Mema Nackasha: We're all friends",
#  "Mema Nackasha: I don't want to start worrying that I can't cuddle you",
#  'Mema Nackasha: Or him',
#  'Mema Nackasha: Or anyone',
#  "Mema Nackasha: or say I'm seeing marie for example",
#  'Mema Nackasha: Ya know',
#  "Guy: Yeah if course but it's just basic sensitivity, you're not expected to go out your way to do anything",
#  "Mema Nackasha: Ok I'll keep the abs to myself",
#  'Guy: I totally get that you just want to relax with your friends and enjoy yourself',
#  "Guy: That's really fair",
#  'Mema Nackasha: Yep',
#  'Mema Nackasha: And I don\'t want to have to think "especially be careful with guy"',
#  'Mema Nackasha: Because of 7 years ago',
#  "Mema Nackasha: Ya know that's tiring",
#  'Mema Nackasha: I thought Jake was sad on the weekend because it was me and you',
#  "Mema Nackasha: But he swears down that wasn't the case",
#  "Guy: I'd hope that you wouldn't have to be especially different around me either",
#  ...]

# %%
chat = []
for i in range(n):
    message = raw_chat[i]
    if message[0] == ' ':
        print(message)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-d529692a26e7> in <module>
#       2 for i in range(n):
#       3     message = raw_chat[i]
# ----> 4     if message[0] == ' ':
#       5         print(message)
#
# IndexError: string index out of range

# %%
chat[11].split('] ')[1]
# Out:
# 'Mema Nackasha: Yeah maybs baby ! Sounds good!'

# %%
for i in range(n):
    if chat[i][0] != '[':
        print(i, chat[i])
# Out:
# 108 ‎[12/09/2016, 19:30:17] Guy: ‎image omitted
# 112 ‎[12/09/2016, 19:32:09] Mema Nackasha: ‎image omitted
# 115 ‎[12/09/2016, 19:39:40] Guy: ‎image omitted
# 208 ‎[05/01/2017, 19:26:21] Guy: ‎image omitted
# 253 ‎[15/01/2017, 19:12:23] Guy: ‎GIF omitted
# 270 ‎[15/01/2017, 19:16:07] Mema Nackasha: ‎image omitted
# 276 ‎[15/01/2017, 19:17:42] Guy: ‎image omitted
# 284 ‎[15/01/2017, 19:29:57] Mema Nackasha: ‎image omitted
# 287 ‎[15/01/2017, 19:42:42] Mema Nackasha: ‎image omitted
# 288 ‎[15/01/2017, 19:42:50] Mema Nackasha: ‎image omitted
# 289 ‎[15/01/2017, 19:42:53] Mema Nackasha: ‎image omitted
# 292 ‎[15/01/2017, 19:45:30] Mema Nackasha: ‎image omitted
# 293 ‎[15/01/2017, 19:46:11] Mema Nackasha: ‎image omitted
# 296 ‎[15/01/2017, 19:47:18] Mema Nackasha: ‎image omitted
# 303 ‎[15/01/2017, 20:15:39] Mema Nackasha: ‎image omitted
# 314 ‎[15/01/2017, 20:43:05] Mema Nackasha: ‎image omitted
# 360 ‎[15/01/2017, 20:57:39] Mema Nackasha: ‎image omitted
# 361 ‎[15/01/2017, 20:57:43] Mema Nackasha: ‎image omitted
# 382 ‎[15/01/2017, 21:11:11] Mema Nackasha: ‎image omitted
# 384 ‎[15/01/2017, 21:11:20] Mema Nackasha: ‎image omitted
# 439 ‎[15/01/2017, 21:29:29] Mema Nackasha: ‎image omitted
# 680 ‎[15/01/2017, 22:29:45] Mema Nackasha: ‎image omitted
# 723 ‎[15/01/2017, 22:48:26] Mema Nackasha: ‎image omitted
# 724 ‎[15/01/2017, 22:48:35] Mema Nackasha: ‎image omitted
# 810 "I'd hate you if you weren't so bloody nice"
# 819 ‎[18/01/2017, 18:31:34] Mema Nackasha: ‎audio omitted
# 909 ‎[22/01/2017, 10:15:27] Mema Nackasha: ‎image omitted
# 941 ‎[23/01/2017, 16:50:01] Mema Nackasha: ‎image omitted
# 1079 ‎[17/02/2017, 10:57:49] Mema Nackasha: ‎image omitted
# 1099 ‎[17/02/2017, 11:10:24] Mema Nackasha: ‎image omitted
# 1100 ‎[17/02/2017, 11:10:40] Mema Nackasha: ‎image omitted
# 1330 ‎[13/03/2017, 09:17:39] Mema Nackasha: ‎image omitted
# 1364 ‎[18/03/2017, 15:24:52] Mema Nackasha: ‎audio omitted
# 1498 ‎[17/04/2017, 12:38:26] Mema Nackasha: ‎image omitted
# 1502 ‎[17/04/2017, 12:42:22] Guy: ‎image omitted
# 1589 ‎[27/05/2017, 13:31:09] Mema Nackasha: ‎image omitted
# 1590 ‎[27/05/2017, 13:31:16] Mema Nackasha: ‎image omitted
# 1591 ‎[27/05/2017, 13:31:26] Mema Nackasha: ‎image omitted
# 1592 ‎[27/05/2017, 13:31:32] Mema Nackasha: ‎image omitted
# 1593 ‎[27/05/2017, 13:31:38] Mema Nackasha: ‎image omitted
# 1594 ‎[27/05/2017, 13:31:42] Mema Nackasha: ‎image omitted
# 1595 ‎[27/05/2017, 13:31:46] Mema Nackasha: ‎image omitted
# 1596 ‎[27/05/2017, 13:31:52] Mema Nackasha: ‎image omitted
# 1597 ‎[27/05/2017, 13:32:02] Mema Nackasha: ‎image omitted
# 1598 ‎[27/05/2017, 13:32:11] Mema Nackasha: ‎image omitted
# 1599 ‎[27/05/2017, 13:32:21] Mema Nackasha: ‎image omitted
# 1600 ‎[27/05/2017, 13:32:27] Mema Nackasha: ‎image omitted
# 1601 ‎[27/05/2017, 13:32:31] Mema Nackasha: ‎image omitted
# 1602 ‎[27/05/2017, 13:32:35] Mema Nackasha: ‎image omitted
# 1603 ‎[27/05/2017, 13:32:39] Mema Nackasha: ‎image omitted
# 1604 ‎[27/05/2017, 13:32:43] Mema Nackasha: ‎image omitted
# 1605 ‎[27/05/2017, 13:32:47] Mema Nackasha: ‎image omitted
# 1606 ‎[27/05/2017, 13:32:49] Mema Nackasha: ‎image omitted
# 1607 ‎[27/05/2017, 13:32:52] Mema Nackasha: ‎image omitted
# 1718 ‎[29/05/2017, 15:43:23] Mema Nackasha: ‎image omitted
# 1745 ‎[02/06/2017, 00:12:01] Mema Nackasha: ‎image omitted
# 1751 ‎[02/06/2017, 08:20:11] Mema Nackasha: ‎image omitted
# 1752 ‎[02/06/2017, 08:26:52] Mema Nackasha: ‎image omitted
# 1809 ‎[13/06/2017, 21:49:17] Mema Nackasha: ‎image omitted
# 1826 ‎[17/06/2017, 16:41:23] Mema Nackasha: ‎image omitted
# 1827 ‎[17/06/2017, 16:41:23] Mema Nackasha: ‎image omitted
# 1831 ‎[17/06/2017, 20:21:18] Mema Nackasha: ‎image omitted
# 1835 ‎[17/06/2017, 20:22:29] Mema Nackasha: ‎image omitted
# 1836 ‎[17/06/2017, 20:22:29] Mema Nackasha: ‎image omitted
# 1837 ‎[17/06/2017, 20:22:30] Mema Nackasha: ‎image omitted
# 1838 ‎[17/06/2017, 20:22:31] Mema Nackasha: ‎image omitted
# 1839 ‎[17/06/2017, 20:22:32] Mema Nackasha: ‎image omitted
# 1840 ‎[17/06/2017, 20:22:32] Mema Nackasha: ‎image omitted
# 1841 ‎[17/06/2017, 20:22:32] Mema Nackasha: ‎image omitted
# 1852 ‎[18/06/2017, 10:07:40] Mema Nackasha: ‎image omitted
# 1869 ‎[21/06/2017, 23:20:36] Mema Nackasha: ‎image omitted
# 2131 ‎[09/07/2017, 17:26:29] Mema Nackasha: ‎image omitted
# 2145 ‎[10/07/2017, 21:55:48] Guy: ‎image omitted
# 2146 ‎[10/07/2017, 21:55:58] Guy: ‎image omitted
# 2147 ‎[10/07/2017, 21:56:05] Guy: ‎image omitted
# 2148 ‎[10/07/2017, 21:56:11] Guy: ‎image omitted
# 2181 ‎[11/07/2017, 19:56:20] Mema Nackasha: ‎image omitted
# 2186 ‎[11/07/2017, 20:09:37] Mema Nackasha: ‎image omitted
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-862056ecdc8f> in <module>
#       1 for i in range(n):
# ----> 2     if chat[i][0] != '[':
#       3         print(i, chat[i])
#
# IndexError: string index out of range
